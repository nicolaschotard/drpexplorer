# %%
import lsst.daf.persistence as dafPersist

# %%
#drp_path = '/sps/lsst/data/clusters/workflow/dc2_test/work/201807002/input/'
drp_path = '/sps/lsst/data/clusters/workflow/weeklies/work/201749004/output'

# %%
butler = dafPersist.Butler(drp_path)

# %%
butler.getKeys('toto')

# %%
repoData = butler._repos.outputs()[0]

# %%
repoData.getParentRepoDatas()

# %%
from drpexplorer.butler import processing

# %%
but = processing.Butler(drp_path='/sps/lsst/data/clusters/workflow/dc2_test/work/201807002/input/')

# %%
but.butler._locate('deepCoadd_skyMap', dafPersist.DataId({}), write=False)

# %%
but.dataIds['raw'][0]
# Out:
# {'channel': '05',
#  'filter': 'r',
#  'raft': '24',
#  'sensor': '12',
#  'snap': 0,
#  'visit': 151687}

# %%
did = but.dataIds['raw'][0]

# %%
but.butler.get('raw_filename', dataId=did)
# Out:
# RuntimeErrorTraceback (most recent call last)
# <ipython-input-9-d9dd1463d1b6> in <module>()
# ----> 1 but.butler.get('raw_filename', dataId=did)
#
# /sps/lsst/software/lsst_distrib/w_2018_07/stack/miniconda3-4.3.21-10a4fa6/Linux64/daf_persistence/14.0-14-g87d16e8+10/python/lsst/daf/persistence/butler.py in get(self, datasetType, dataId, immediate, **rest)
#    1406         dataId.update(**rest)
#    1407
# -> 1408         location = self._locate(datasetType, dataId, write=False)
#    1409         if location is None:
#    1410             raise NoResults("No locations for get:", datasetType, dataId)
#
# /sps/lsst/software/lsst_distrib/w_2018_07/stack/miniconda3-4.3.21-10a4fa6/Linux64/daf_persistence/14.0-14-g87d16e8+10/python/lsst/daf/persistence/butler.py in _locate(self, datasetType, dataId, write)
#    1327             components = components[1:]
#    1328             try:
# -> 1329                 location = repoData.repo.map(datasetType, dataId, write=write)
#    1330             except NoResults:
#    1331                 continue
#
# /sps/lsst/software/lsst_distrib/w_2018_07/stack/miniconda3-4.3.21-10a4fa6/Linux64/daf_persistence/14.0-14-g87d16e8+10/python/lsst/daf/persistence/repository.py in map(self, *args, **kwargs)
#     244         if self._mapper is None:
#     245             raise RuntimeError("No mapper assigned to Repository")
# --> 246         loc = self._mapper.map(*args, **kwargs)
#     247         if loc is None:
#     248             return None
#
# /sps/lsst/software/lsst_distrib/w_2018_07/stack/miniconda3-4.3.21-10a4fa6/Linux64/daf_persistence/14.0-14-g87d16e8+10/python/lsst/daf/persistence/mapper.py in map(self, datasetType, dataId, write)
#     164         """
#     165         func = getattr(self, 'map_' + datasetType)
# --> 166         return func(self.validate(dataId), write)
#     167
#     168     def canStandardize(self, datasetType):
#
# /sps/lsst/software/lsst_distrib/w_2018_07/stack/miniconda3-4.3.21-10a4fa6/Linux64/obs_lsstSim/14.0-9-gca35c49/python/lsst/obs/lsstSim/lsstSimMapper.py in validate(self, dataId)
#     143             else:
#     144                 if not re.search(r'^(\d),(\d)$', val):
# --> 145                     raise RuntimeError("Invalid %s identifier: %r" % (component, val))
#     146         return dataId
#     147
#
# RuntimeError: Invalid raft identifier: '24'

# %%
mappers = but.repoData.repo.mappers()[0]   #_mapper, 'map_deepCoadd_skyMap')

# %%
but.repoData.repo.

# %%
but.butler._locate('deepCoadd_skyMap', dafPersist.DataId({}), write=False)

# %%
but.butler._locate('deepCoadd_skmap', dafPersist.DataId({}), write=False)
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-49-4478f6a579ca> in <module>()
# ----> 1 but.butler._locate('deepCoadd_skmap', dafPersist.DataId({}), write=False)
#
# /sps/lsst/software/lsst_distrib/w_2018_07/stack/miniconda3-4.3.21-10a4fa6/Linux64/daf_persistence/14.0-14-g87d16e8+10/python/lsst/daf/persistence/butler.py in _locate(self, datasetType, dataId, write)
#    1327             components = components[1:]
#    1328             try:
# -> 1329                 location = repoData.repo.map(datasetType, dataId, write=write)
#    1330             except NoResults:
#    1331                 continue
#
# /sps/lsst/software/lsst_distrib/w_2018_07/stack/miniconda3-4.3.21-10a4fa6/Linux64/daf_persistence/14.0-14-g87d16e8+10/python/lsst/daf/persistence/repository.py in map(self, *args, **kwargs)
#     244         if self._mapper is None:
#     245             raise RuntimeError("No mapper assigned to Repository")
# --> 246         loc = self._mapper.map(*args, **kwargs)
#     247         if loc is None:
#     248             return None
#
# /sps/lsst/software/lsst_distrib/w_2018_07/stack/miniconda3-4.3.21-10a4fa6/Linux64/daf_persistence/14.0-14-g87d16e8+10/python/lsst/daf/persistence/mapper.py in map(self, datasetType, dataId, write)
#     163             catches this and will look in the next Repository if there is one.
#     164         """
# --> 165         func = getattr(self, 'map_' + datasetType)
#     166         return func(self.validate(dataId), write)
#     167
#
# AttributeError: 'LsstSimMapper' object has no attribute 'map_deepCoadd_skmap'

# %%
but.butler._locate??

# %%
import lsst.daf.persistence as dafPersist

# %%
but.butler._repos.inputs()[0].repo.map('deepCoadd_skmap', dafPersist.DataId({}), write=False)
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-53-90c7c6d9dbff> in <module>()
# ----> 1 but.butler._repos.inputs()[0].repo.map('deepCoadd_skmap', dafPersist.DataId({}), write=False)
#
# /sps/lsst/software/lsst_distrib/w_2018_07/stack/miniconda3-4.3.21-10a4fa6/Linux64/daf_persistence/14.0-14-g87d16e8+10/python/lsst/daf/persistence/repository.py in map(self, *args, **kwargs)
#     244         if self._mapper is None:
#     245             raise RuntimeError("No mapper assigned to Repository")
# --> 246         loc = self._mapper.map(*args, **kwargs)
#     247         if loc is None:
#     248             return None
#
# /sps/lsst/software/lsst_distrib/w_2018_07/stack/miniconda3-4.3.21-10a4fa6/Linux64/daf_persistence/14.0-14-g87d16e8+10/python/lsst/daf/persistence/mapper.py in map(self, datasetType, dataId, write)
#     163             catches this and will look in the next Repository if there is one.
#     164         """
# --> 165         func = getattr(self, 'map_' + datasetType)
#     166         return func(self.validate(dataId), write)
#     167
#
# AttributeError: 'LsstSimMapper' object has no attribute 'map_deepCoadd_skmap'

# %%
repo = but.butler._repos.inputs()[0].repo

# %%
repo._mapper.map('deepCoadd_skyMap', dafPersist.DataId({}), write=False)
# Out:
# ButlerLocation(pythonType='lsst.skymap.BaseSkyMap', cppType='ignored', storageName='PickleStorage', storage=PosixStorage(root=/sps/lsst/data/clusters/workflow/dc2_test/work/201807002/input), locationList=['deepCoadd/skyMap.pickle'], additionalData=<lsst.daf.base.propertyContainer.propertySet.PropertySet object at 0x7fc95c118458>, mapper=<weakproxy at 0x7fc961390728 to LsstSimMapper at 0x7fc9ac9557b8>, dataId=DataId(initialdata={}, tag=set()))
