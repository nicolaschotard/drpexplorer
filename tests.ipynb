# %%
from drpexplorer.butler import processing

# %%
but = processing.Butler(drp_path='/sps/lsst/data/clusters/workflow/weeklies/work/201749004/output')

# %%
but.configs['detectCoaddSources_config']
# Out:
# {'coaddName': 'deep',
#  'detection': {'adjustBackground': 0.0,
#   'background': {'algorithm': 'AKIMA_SPLINE',
#    'approxOrderX': 6,
#    'approxOrderY': -1,
#    'binSize': 4096,
#    'binSizeX': 0,
#    'binSizeY': 0,
#    'ignoredPixelMask': ['BAD',
#     'EDGE',
#     'DETECTED',
#     'DETECTED_NEGATIVE',
#     'NO_DATA'],
#    'isNanSafe': False,
#    'statisticsProperty': 'MEANCLIP',
#    'undersampleStyle': 'REDUCE_INTERP_ORDER',
#    'useApprox': False,
#    'weighting': True},
#   'doTempLocalBackground': True,
#   'includeThresholdMultiplier': 1.0,
#   'isotropicGrow': True,
#   'minPixels': 1,
#   'nPeaksMaxSimple': 1,
#   'nSigmaForKernel': 7.0,
#   'nSigmaToGrow': 2.4,
#   'prelimThresholdFactor': 0.5,
#   'reEstimateBackground': True,
#   'returnOriginalFootprints': False,
#   'skyObjects': {'avoidMask': ['DETECTED',
#     'DETECTED_NEGATIVE',
#     'BAD',
#     'NO_DATA'],
#    'growMask': 0,
#    'nSources': 100,
#    'nTrialSources': None,
#    'nTrialSourcesMultiplier': 5,
#    'sourceRadius': 8.0},
#   'statsMask': ['BAD', 'SAT', 'EDGE', 'NO_DATA'],
#   'tempLocalBackground': {'algorithm': 'AKIMA_SPLINE',
#    'approxOrderX': 6,
#    'approxOrderY': -1,
#    'binSize': 64,
#    'binSizeX': 0,
#    'binSizeY': 0,
#    'ignoredPixelMask': ['BAD',
#     'EDGE',
#     'DETECTED',
#     'DETECTED_NEGATIVE',
#     'NO_DATA'],
#    'isNanSafe': False,
#    'statisticsProperty': 'MEANCLIP',
#    'undersampleStyle': 'REDUCE_INTERP_ORDER',
#    'useApprox': False,
#    'weighting': True},
#   'thresholdPolarity': 'positive',
#   'thresholdType': 'pixel_stdev',
#   'thresholdValue': 5.0},
#  'doInsertFakes': False,
#  'doScaleVariance': True,
#  'insertFakes': {'maskPlaneName': 'FAKE'},
#  'mask': ['DETECTED', 'BAD', 'SAT', 'NO_DATA', 'INTRP']}

# %%
len([d for d in but.datasetTypes if d.endswith("_config")])
# Out:
# 34

# %%
but.butler.datasetExists('processCcd_config', dataId=but.dataIds['raw'][0])
# Out:
# False

# %%
sorted(but.schemas.keys()),sorted(but.configs.keys())
# Out:
# (['deepCoadd_det_schema',
#   'deepCoadd_forced_src_schema',
#   'deepCoadd_meas_schema',
#   'deepCoadd_mergeDet_schema',
#   'deepCoadd_peak_schema',
#   'deepCoadd_ref_schema',
#   'forced_src_schema',
#   'icSrc_schema',
#   'src_schema'],
#  ['dcrCoadd_forced_config',
#   'deepCoadd_forced_config',
#   'detectCoaddSources_config',
#   'forcedPhotCcd_config',
#   'forcedPhotCoadd_config',
#   'measureCoaddSources_config',
#   'mergeCoaddDetections_config',
#   'mergeCoaddMeasurements_config',
#   'singleFrameDriver_config'])

# %%
but.configs['deepCoadd_forced_config'].keys()
# Out:
# dict_keys(['references', 'measurement', 'coaddName', 'doApCorr', 'applyApCorr', 'catalogCalculation', 'footprintDatasetName'])

# %%
schema = but.schemas['deepCoadd_meas_schema'].asAstropy()

# %%
#sch = schema.show_in_notebook()._repr_html_()

# %%
{col: {'description': schema[col].description, 'unit': schema[col].unit, 'dtype': schema[col].dtype} for col in schema.colnames}
# Out:
# {'base_Blendedness_abs_child_xx': {'description': 'shape of the child, measured with a Gaussian weight matched to the child',
#   'dtype': dtype('float64'),
#   'unit': Unit("pix2")},
#  'base_Blendedness_abs_child_xy': {'description': 'shape of the child, measured with a Gaussian weight matched to the child',
#   'dtype': dtype('float64'),
#   'unit': Unit("pix2")},
#  'base_Blendedness_abs_child_yy': {'description': 'shape of the child, measured with a Gaussian weight matched to the child',
#   'dtype': dtype('float64'),
#   'unit': Unit("pix2")},
#  'base_Blendedness_abs_flux': {'description': 'measure of how flux is affected by neighbors: (1 - flux.child/flux.parent)',
#   'dtype': dtype('float64'),
#   'unit': None},
#  'base_Blendedness_abs_flux_child': {'description': 'flux of the child, measured with a Gaussian weight matched to the child',
#   'dtype': dtype('float64'),
#   'unit': Unit("ct")},
#  'base_Blendedness_abs_flux_parent': {'description': 'flux of the parent, measured with a Gaussian weight matched to the child',
#   'dtype': dtype('float64'),
#   'unit': Unit("ct")},
#  'base_Blendedness_abs_parent_xx': {'description': 'shape of the parent, measured with a Gaussian weight matched to the child',
#   'dtype': dtype('float64'),
#   'unit': Unit("pix2")},
#  'base_Blendedness_abs_parent_xy': {'description': 'shape of the parent, measured with a Gaussian weight matched to the child',
#   'dtype': dtype('float64'),
#   'unit': Unit("pix2")},
#  'base_Blendedness_abs_parent_yy': {'description': 'shape of the parent, measured with a Gaussian weight matched to the child',
#   'dtype': dtype('float64'),
#   'unit': Unit("pix2")},
#  'base_Blendedness_flag': {'description': 'General Failure Flag',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_Blendedness_flag_noCentroid': {'description': 'Object has no centroid',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_Blendedness_flag_noShape': {'description': 'Object has no shape',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_Blendedness_old': {'description': 'blendedness from dot products: (child.dot(parent)/child.dot(child) - 1)',
#   'dtype': dtype('float64'),
#   'unit': None},
#  'base_Blendedness_raw_child_xx': {'description': 'shape of the child, measured with a Gaussian weight matched to the child',
#   'dtype': dtype('float64'),
#   'unit': Unit("pix2")},
#  'base_Blendedness_raw_child_xy': {'description': 'shape of the child, measured with a Gaussian weight matched to the child',
#   'dtype': dtype('float64'),
#   'unit': Unit("pix2")},
#  'base_Blendedness_raw_child_yy': {'description': 'shape of the child, measured with a Gaussian weight matched to the child',
#   'dtype': dtype('float64'),
#   'unit': Unit("pix2")},
#  'base_Blendedness_raw_flux': {'description': 'measure of how flux is affected by neighbors: (1 - flux.child/flux.parent)',
#   'dtype': dtype('float64'),
#   'unit': None},
#  'base_Blendedness_raw_flux_child': {'description': 'flux of the child, measured with a Gaussian weight matched to the child',
#   'dtype': dtype('float64'),
#   'unit': Unit("ct")},
#  'base_Blendedness_raw_flux_parent': {'description': 'flux of the parent, measured with a Gaussian weight matched to the child',
#   'dtype': dtype('float64'),
#   'unit': Unit("ct")},
#  'base_Blendedness_raw_parent_xx': {'description': 'shape of the parent, measured with a Gaussian weight matched to the child',
#   'dtype': dtype('float64'),
#   'unit': Unit("pix2")},
#  'base_Blendedness_raw_parent_xy': {'description': 'shape of the parent, measured with a Gaussian weight matched to the child',
#   'dtype': dtype('float64'),
#   'unit': Unit("pix2")},
#  'base_Blendedness_raw_parent_yy': {'description': 'shape of the parent, measured with a Gaussian weight matched to the child',
#   'dtype': dtype('float64'),
#   'unit': Unit("pix2")},
#  'base_CircularApertureFlux_12_0_flag': {'description': 'General Failure Flag',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_CircularApertureFlux_12_0_flag_apertureTruncated': {'description': 'aperture did not fit within measurement image',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_CircularApertureFlux_12_0_flux': {'description': 'flux within 12.000000-pixel aperture',
#   'dtype': dtype('float64'),
#   'unit': Unit("ct")},
#  'base_CircularApertureFlux_12_0_fluxSigma': {'description': '1-sigma flux uncertainty',
#   'dtype': dtype('float64'),
#   'unit': Unit("ct")},
#  'base_CircularApertureFlux_17_0_flag': {'description': 'General Failure Flag',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_CircularApertureFlux_17_0_flag_apertureTruncated': {'description': 'aperture did not fit within measurement image',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_CircularApertureFlux_17_0_flux': {'description': 'flux within 17.000000-pixel aperture',
#   'dtype': dtype('float64'),
#   'unit': Unit("ct")},
#  'base_CircularApertureFlux_17_0_fluxSigma': {'description': '1-sigma flux uncertainty',
#   'dtype': dtype('float64'),
#   'unit': Unit("ct")},
#  'base_CircularApertureFlux_25_0_flag': {'description': 'General Failure Flag',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_CircularApertureFlux_25_0_flag_apertureTruncated': {'description': 'aperture did not fit within measurement image',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_CircularApertureFlux_25_0_flux': {'description': 'flux within 25.000000-pixel aperture',
#   'dtype': dtype('float64'),
#   'unit': Unit("ct")},
#  'base_CircularApertureFlux_25_0_fluxSigma': {'description': '1-sigma flux uncertainty',
#   'dtype': dtype('float64'),
#   'unit': Unit("ct")},
#  'base_CircularApertureFlux_35_0_flag': {'description': 'General Failure Flag',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_CircularApertureFlux_35_0_flag_apertureTruncated': {'description': 'aperture did not fit within measurement image',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_CircularApertureFlux_35_0_flux': {'description': 'flux within 35.000000-pixel aperture',
#   'dtype': dtype('float64'),
#   'unit': Unit("ct")},
#  'base_CircularApertureFlux_35_0_fluxSigma': {'description': '1-sigma flux uncertainty',
#   'dtype': dtype('float64'),
#   'unit': Unit("ct")},
#  'base_CircularApertureFlux_3_0_flag': {'description': 'General Failure Flag',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_CircularApertureFlux_3_0_flag_apertureTruncated': {'description': 'aperture did not fit within measurement image',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_CircularApertureFlux_3_0_flag_sincCoeffsTruncated': {'description': 'full sinc coefficient image did not fit within measurement image',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_CircularApertureFlux_3_0_flux': {'description': 'flux within 3.000000-pixel aperture',
#   'dtype': dtype('float64'),
#   'unit': Unit("ct")},
#  'base_CircularApertureFlux_3_0_fluxSigma': {'description': '1-sigma flux uncertainty',
#   'dtype': dtype('float64'),
#   'unit': Unit("ct")},
#  'base_CircularApertureFlux_4_5_flag': {'description': 'General Failure Flag',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_CircularApertureFlux_4_5_flag_apertureTruncated': {'description': 'aperture did not fit within measurement image',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_CircularApertureFlux_4_5_flag_sincCoeffsTruncated': {'description': 'full sinc coefficient image did not fit within measurement image',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_CircularApertureFlux_4_5_flux': {'description': 'flux within 4.500000-pixel aperture',
#   'dtype': dtype('float64'),
#   'unit': Unit("ct")},
#  'base_CircularApertureFlux_4_5_fluxSigma': {'description': '1-sigma flux uncertainty',
#   'dtype': dtype('float64'),
#   'unit': Unit("ct")},
#  'base_CircularApertureFlux_50_0_flag': {'description': 'General Failure Flag',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_CircularApertureFlux_50_0_flag_apertureTruncated': {'description': 'aperture did not fit within measurement image',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_CircularApertureFlux_50_0_flux': {'description': 'flux within 50.000000-pixel aperture',
#   'dtype': dtype('float64'),
#   'unit': Unit("ct")},
#  'base_CircularApertureFlux_50_0_fluxSigma': {'description': '1-sigma flux uncertainty',
#   'dtype': dtype('float64'),
#   'unit': Unit("ct")},
#  'base_CircularApertureFlux_6_0_flag': {'description': 'General Failure Flag',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_CircularApertureFlux_6_0_flag_apertureTruncated': {'description': 'aperture did not fit within measurement image',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_CircularApertureFlux_6_0_flag_sincCoeffsTruncated': {'description': 'full sinc coefficient image did not fit within measurement image',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_CircularApertureFlux_6_0_flux': {'description': 'flux within 6.000000-pixel aperture',
#   'dtype': dtype('float64'),
#   'unit': Unit("ct")},
#  'base_CircularApertureFlux_6_0_fluxSigma': {'description': '1-sigma flux uncertainty',
#   'dtype': dtype('float64'),
#   'unit': Unit("ct")},
#  'base_CircularApertureFlux_70_0_flag': {'description': 'General Failure Flag',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_CircularApertureFlux_70_0_flag_apertureTruncated': {'description': 'aperture did not fit within measurement image',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_CircularApertureFlux_70_0_flux': {'description': 'flux within 70.000000-pixel aperture',
#   'dtype': dtype('float64'),
#   'unit': Unit("ct")},
#  'base_CircularApertureFlux_70_0_fluxSigma': {'description': '1-sigma flux uncertainty',
#   'dtype': dtype('float64'),
#   'unit': Unit("ct")},
#  'base_CircularApertureFlux_9_0_flag': {'description': 'General Failure Flag',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_CircularApertureFlux_9_0_flag_apertureTruncated': {'description': 'aperture did not fit within measurement image',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_CircularApertureFlux_9_0_flag_sincCoeffsTruncated': {'description': 'full sinc coefficient image did not fit within measurement image',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_CircularApertureFlux_9_0_flux': {'description': 'flux within 9.000000-pixel aperture',
#   'dtype': dtype('float64'),
#   'unit': Unit("ct")},
#  'base_CircularApertureFlux_9_0_fluxSigma': {'description': '1-sigma flux uncertainty',
#   'dtype': dtype('float64'),
#   'unit': Unit("ct")},
#  'base_CircularApertureFlux_flag_badCentroid': {'description': 'General Failure Flag',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_CircularApertureFlux_flag_badCentroid_almostNoSecondDerivative': {'description': 'Almost vanishing second derivative',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_CircularApertureFlux_flag_badCentroid_edge': {'description': 'Object too close to edge',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_CircularApertureFlux_flag_badCentroid_noSecondDerivative': {'description': 'Vanishing second derivative',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_CircularApertureFlux_flag_badCentroid_notAtMaximum': {'description': 'Object is not at a maximum',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_CircularApertureFlux_flag_badCentroid_resetToPeak': {'description': 'set if CentroidChecker reset the centroid',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_ClassificationExtendedness_flag': {'description': 'Set to 1 for any fatal failure.',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_ClassificationExtendedness_value': {'description': 'Set to 1 for extended sources, 0 for point sources.',
#   'dtype': dtype('float64'),
#   'unit': None},
#  'base_FootprintArea_value': {'description': "Number of pixels in the source''s detection footprint.",
#   'dtype': dtype('int32'),
#   'unit': Unit("pix")},
#  'base_GaussianCentroid_flag': {'description': 'General Failure Flag',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_GaussianCentroid_flag_badInitialCentroid': {'description': 'General Failure Flag',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_GaussianCentroid_flag_badInitialCentroid_almostNoSecondDerivative': {'description': 'Almost vanishing second derivative',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_GaussianCentroid_flag_badInitialCentroid_edge': {'description': 'Object too close to edge',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_GaussianCentroid_flag_badInitialCentroid_noSecondDerivative': {'description': 'Vanishing second derivative',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_GaussianCentroid_flag_badInitialCentroid_notAtMaximum': {'description': 'Object is not at a maximum',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_GaussianCentroid_flag_badInitialCentroid_resetToPeak': {'description': 'set if CentroidChecker reset the centroid',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_GaussianCentroid_flag_noPeak': {'description': 'Fitted Centroid has a negative peak',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_GaussianCentroid_flag_resetToPeak': {'description': 'set if CentroidChecker reset the centroid',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_GaussianCentroid_x': {'description': 'centroid from Gaussian Centroid algorithm',
#   'dtype': dtype('float64'),
#   'unit': Unit("pix")},
#  'base_GaussianCentroid_y': {'description': 'centroid from Gaussian Centroid algorithm',
#   'dtype': dtype('float64'),
#   'unit': Unit("pix")},
#  'base_GaussianFlux_apCorr': {'description': 'aperture correction applied to base_GaussianFlux',
#   'dtype': dtype('float64'),
#   'unit': None},
#  'base_GaussianFlux_apCorrSigma': {'description': 'aperture correction applied to base_GaussianFlux',
#   'dtype': dtype('float64'),
#   'unit': None},
#  'base_GaussianFlux_flag': {'description': 'General Failure Flag',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_GaussianFlux_flag_apCorr': {'description': 'set if unable to aperture correct base_GaussianFlux',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_GaussianFlux_flag_badCentroid': {'description': 'General Failure Flag',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_GaussianFlux_flag_badCentroid_almostNoSecondDerivative': {'description': 'Almost vanishing second derivative',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_GaussianFlux_flag_badCentroid_edge': {'description': 'Object too close to edge',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_GaussianFlux_flag_badCentroid_noSecondDerivative': {'description': 'Vanishing second derivative',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_GaussianFlux_flag_badCentroid_notAtMaximum': {'description': 'Object is not at a maximum',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_GaussianFlux_flag_badCentroid_resetToPeak': {'description': 'set if CentroidChecker reset the centroid',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_GaussianFlux_flag_badShape': {'description': 'general failure flag, set if anything went wrong',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_GaussianFlux_flag_badShape_no_pixels': {'description': 'no pixels to measure',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_GaussianFlux_flag_badShape_not_contained': {'description': 'center not contained in footprint bounding box',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_GaussianFlux_flag_badShape_parent_source': {'description': 'parent source, ignored',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_GaussianFlux_flux': {'description': 'flux from Gaussian Flux algorithm',
#   'dtype': dtype('float64'),
#   'unit': Unit("ct")},
#  'base_GaussianFlux_fluxSigma': {'description': '1-sigma flux uncertainty',
#   'dtype': dtype('float64'),
#   'unit': Unit("ct")},
#  'base_InputCount_flag': {'description': 'Set for any fatal failure',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_InputCount_flag_badCentroid': {'description': 'General Failure Flag',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_InputCount_flag_badCentroid_almostNoSecondDerivative': {'description': 'Almost vanishing second derivative',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_InputCount_flag_badCentroid_edge': {'description': 'Object too close to edge',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_InputCount_flag_badCentroid_noSecondDerivative': {'description': 'Vanishing second derivative',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_InputCount_flag_badCentroid_notAtMaximum': {'description': 'Object is not at a maximum',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_InputCount_flag_badCentroid_resetToPeak': {'description': 'set if CentroidChecker reset the centroid',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_InputCount_flag_noInputs': {'description': 'No coadd inputs available',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_InputCount_value': {'description': 'Number of images contributing at center, not including anyclipping',
#   'dtype': dtype('int32'),
#   'unit': None},
#  'base_NaiveCentroid_flag': {'description': 'General Failure Flag',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_NaiveCentroid_flag_badInitialCentroid': {'description': 'General Failure Flag',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_NaiveCentroid_flag_badInitialCentroid_almostNoSecondDerivative': {'description': 'Almost vanishing second derivative',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_NaiveCentroid_flag_badInitialCentroid_edge': {'description': 'Object too close to edge',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_NaiveCentroid_flag_badInitialCentroid_noSecondDerivative': {'description': 'Vanishing second derivative',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_NaiveCentroid_flag_badInitialCentroid_notAtMaximum': {'description': 'Object is not at a maximum',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_NaiveCentroid_flag_badInitialCentroid_resetToPeak': {'description': 'set if CentroidChecker reset the centroid',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_NaiveCentroid_flag_edge': {'description': 'Object too close to edge',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_NaiveCentroid_flag_noCounts': {'description': 'Object to be centroided has no counts',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_NaiveCentroid_flag_resetToPeak': {'description': 'set if CentroidChecker reset the centroid',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_NaiveCentroid_x': {'description': 'centroid from Naive Centroid algorithm',
#   'dtype': dtype('float64'),
#   'unit': Unit("pix")},
#  'base_NaiveCentroid_y': {'description': 'centroid from Naive Centroid algorithm',
#   'dtype': dtype('float64'),
#   'unit': Unit("pix")},
#  'base_PixelFlags_flag': {'description': 'general failure flag, set if anything went wring',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_PixelFlags_flag_bad': {'description': 'Bad pixel in the Source footprint',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_PixelFlags_flag_clipped': {'description': 'Source footprint includes CLIPPED pixels',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_PixelFlags_flag_cr': {'description': 'Cosmic ray in the Source footprint',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_PixelFlags_flag_crCenter': {'description': 'Cosmic ray in the Source center',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_PixelFlags_flag_edge': {'description': 'Source is outside usable exposure region (masked EDGE or NO_DATA)',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_PixelFlags_flag_inexact_psf': {'description': 'Source footprint includes INEXACT_PSF pixels',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_PixelFlags_flag_interpolated': {'description': 'Interpolated pixel in the Source footprint',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_PixelFlags_flag_interpolatedCenter': {'description': 'Interpolated pixel in the Source center',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_PixelFlags_flag_offimage': {'description': 'Source center is off image',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_PixelFlags_flag_saturated': {'description': 'Saturated pixel in the Source footprint',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_PixelFlags_flag_saturatedCenter': {'description': 'Saturated pixel in the Source center',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_PixelFlags_flag_sensor_edge': {'description': 'Source footprint includes SENSOR_EDGE pixels',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_PixelFlags_flag_suspect': {'description': "Source''s footprint includes suspect pixels",
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_PixelFlags_flag_suspectCenter': {'description': "Source''s center is close to suspect pixels",
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_PsfFlux_apCorr': {'description': 'aperture correction applied to base_PsfFlux',
#   'dtype': dtype('float64'),
#   'unit': None},
#  'base_PsfFlux_apCorrSigma': {'description': 'aperture correction applied to base_PsfFlux',
#   'dtype': dtype('float64'),
#   'unit': None},
#  'base_PsfFlux_flag': {'description': 'General Failure Flag',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_PsfFlux_flag_apCorr': {'description': 'set if unable to aperture correct base_PsfFlux',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_PsfFlux_flag_badCentroid': {'description': 'General Failure Flag',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_PsfFlux_flag_badCentroid_almostNoSecondDerivative': {'description': 'Almost vanishing second derivative',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_PsfFlux_flag_badCentroid_edge': {'description': 'Object too close to edge',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_PsfFlux_flag_badCentroid_noSecondDerivative': {'description': 'Vanishing second derivative',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_PsfFlux_flag_badCentroid_notAtMaximum': {'description': 'Object is not at a maximum',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_PsfFlux_flag_badCentroid_resetToPeak': {'description': 'set if CentroidChecker reset the centroid',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_PsfFlux_flag_edge': {'description': 'object was too close to the edge of the image to use the full PSF model',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_PsfFlux_flag_noGoodPixels': {'description': 'not enough non-rejected pixels in data to attempt the fit',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_PsfFlux_flux': {'description': 'flux derived from linear least-squares fit of PSF model',
#   'dtype': dtype('float64'),
#   'unit': Unit("ct")},
#  'base_PsfFlux_fluxSigma': {'description': '1-sigma flux uncertainty',
#   'dtype': dtype('float64'),
#   'unit': Unit("ct")},
#  'base_SdssCentroid_flag': {'description': 'General Failure Flag',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_SdssCentroid_flag_almostNoSecondDerivative': {'description': 'Almost vanishing second derivative',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_SdssCentroid_flag_edge': {'description': 'Object too close to edge',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_SdssCentroid_flag_noSecondDerivative': {'description': 'Vanishing second derivative',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_SdssCentroid_flag_notAtMaximum': {'description': 'Object is not at a maximum',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_SdssCentroid_flag_resetToPeak': {'description': 'set if CentroidChecker reset the centroid',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_SdssCentroid_x': {'description': 'centroid from Sdss Centroid algorithm',
#   'dtype': dtype('float64'),
#   'unit': Unit("pix")},
#  'base_SdssCentroid_xSigma': {'description': '1-sigma uncertainty on x position',
#   'dtype': dtype('float32'),
#   'unit': Unit("pix")},
#  'base_SdssCentroid_y': {'description': 'centroid from Sdss Centroid algorithm',
#   'dtype': dtype('float64'),
#   'unit': Unit("pix")},
#  'base_SdssCentroid_ySigma': {'description': '1-sigma uncertainty on y position',
#   'dtype': dtype('float32'),
#   'unit': Unit("pix")},
#  'base_SdssShape_flag': {'description': 'General Failure Flag',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_SdssShape_flag_badCentroid': {'description': 'General Failure Flag',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_SdssShape_flag_badCentroid_almostNoSecondDerivative': {'description': 'Almost vanishing second derivative',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_SdssShape_flag_badCentroid_edge': {'description': 'Object too close to edge',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_SdssShape_flag_badCentroid_noSecondDerivative': {'description': 'Vanishing second derivative',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_SdssShape_flag_badCentroid_notAtMaximum': {'description': 'Object is not at a maximum',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_SdssShape_flag_badCentroid_resetToPeak': {'description': 'set if CentroidChecker reset the centroid',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_SdssShape_flag_maxIter': {'description': 'Too many iterations in adaptive moments',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_SdssShape_flag_psf': {'description': 'Failure in measuring PSF model shape',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_SdssShape_flag_shift': {'description': 'centroid shifted by more than the maximum allowed amount',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_SdssShape_flag_unweighted': {'description': 'Weighted moments converged to an invalid value; using unweighted moments',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_SdssShape_flag_unweightedBad': {'description': 'Both weighted and unweighted moments were invalid',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_SdssShape_flux': {'description': 'elliptical Gaussian adaptive moments',
#   'dtype': dtype('float64'),
#   'unit': Unit("ct")},
#  'base_SdssShape_fluxSigma': {'description': '1-sigma flux uncertainty',
#   'dtype': dtype('float64'),
#   'unit': Unit("ct")},
#  'base_SdssShape_flux_xx_Cov': {'description': 'uncertainty covariance between base_SdssShape_flux and base_SdssShape_xx',
#   'dtype': dtype('float32'),
#   'unit': Unit("ct pix2")},
#  'base_SdssShape_flux_xy_Cov': {'description': 'uncertainty covariance between base_SdssShape_flux and base_SdssShape_xy',
#   'dtype': dtype('float32'),
#   'unit': Unit("ct pix2")},
#  'base_SdssShape_flux_yy_Cov': {'description': 'uncertainty covariance between base_SdssShape_flux and base_SdssShape_yy',
#   'dtype': dtype('float32'),
#   'unit': Unit("ct pix2")},
#  'base_SdssShape_psf_xx': {'description': 'adaptive moments of the PSF model at the object position',
#   'dtype': dtype('float64'),
#   'unit': Unit("pix2")},
#  'base_SdssShape_psf_xy': {'description': 'adaptive moments of the PSF model at the object position',
#   'dtype': dtype('float64'),
#   'unit': Unit("pix2")},
#  'base_SdssShape_psf_yy': {'description': 'adaptive moments of the PSF model at the object position',
#   'dtype': dtype('float64'),
#   'unit': Unit("pix2")},
#  'base_SdssShape_x': {'description': 'elliptical Gaussian adaptive moments',
#   'dtype': dtype('float64'),
#   'unit': Unit("pix")},
#  'base_SdssShape_xx': {'description': 'elliptical Gaussian adaptive moments',
#   'dtype': dtype('float64'),
#   'unit': Unit("pix2")},
#  'base_SdssShape_xxSigma': {'description': '1-sigma uncertainty on xx moment',
#   'dtype': dtype('float32'),
#   'unit': Unit("pix2")},
#  'base_SdssShape_xy': {'description': 'elliptical Gaussian adaptive moments',
#   'dtype': dtype('float64'),
#   'unit': Unit("pix2")},
#  'base_SdssShape_xySigma': {'description': '1-sigma uncertainty on xy moment',
#   'dtype': dtype('float32'),
#   'unit': Unit("pix2")},
#  'base_SdssShape_y': {'description': 'elliptical Gaussian adaptive moments',
#   'dtype': dtype('float64'),
#   'unit': Unit("pix")},
#  'base_SdssShape_yy': {'description': 'elliptical Gaussian adaptive moments',
#   'dtype': dtype('float64'),
#   'unit': Unit("pix2")},
#  'base_SdssShape_yySigma': {'description': '1-sigma uncertainty on yy moment',
#   'dtype': dtype('float32'),
#   'unit': Unit("pix2")},
#  'base_Variance_flag': {'description': 'Set for any fatal failure',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_Variance_flag_badCentroid': {'description': 'General Failure Flag',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_Variance_flag_badCentroid_almostNoSecondDerivative': {'description': 'Almost vanishing second derivative',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_Variance_flag_badCentroid_edge': {'description': 'Object too close to edge',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_Variance_flag_badCentroid_noSecondDerivative': {'description': 'Vanishing second derivative',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_Variance_flag_badCentroid_notAtMaximum': {'description': 'Object is not at a maximum',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_Variance_flag_badCentroid_resetToPeak': {'description': 'set if CentroidChecker reset the centroid',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_Variance_flag_emptyFootprint': {'description': 'Set to True when the footprint has no usable pixels',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'base_Variance_value': {'description': 'Variance at object position',
#   'dtype': dtype('float64'),
#   'unit': None},
#  'calib_psfCandidate': {'description': 'Propagated from visits',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'calib_psfUsed': {'description': 'Propagated from visits',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'coord_dec': {'description': 'position in ra/dec',
#   'dtype': dtype('float64'),
#   'unit': Unit("rad")},
#  'coord_ra': {'description': 'position in ra/dec',
#   'dtype': dtype('float64'),
#   'unit': Unit("rad")},
#  'deblend_deblendedAsPsf': {'description': 'Deblender thought this source looked like a PSF',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'deblend_hasStrayFlux': {'description': 'This source was assigned some stray flux',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'deblend_masked': {'description': 'Parent footprint was predominantly masked',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'deblend_nChild': {'description': 'Number of children this object has (defaults to 0)',
#   'dtype': dtype('int32'),
#   'unit': None},
#  'deblend_parentTooBig': {'description': 'Parent footprint covered too many pixels',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'deblend_patchedTemplate': {'description': 'This source was near an image edge and the deblender used "patched" edge-handling.',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'deblend_psfCenter_x': {'description': 'If deblended-as-psf, the PSF centroid',
#   'dtype': dtype('float64'),
#   'unit': Unit("pix")},
#  'deblend_psfCenter_y': {'description': 'If deblended-as-psf, the PSF centroid',
#   'dtype': dtype('float64'),
#   'unit': Unit("pix")},
#  'deblend_psfFlux': {'description': 'If deblended-as-psf, the PSF flux',
#   'dtype': dtype('float64'),
#   'unit': None},
#  'deblend_rampedTemplate': {'description': 'This source was near an image edge and the deblender used "ramp" edge-handling.',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'deblend_skipped': {'description': 'Deblender skipped this source',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'deblend_tooManyPeaks': {'description': 'Source had too many peaks; only the brightest were included',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'detect_isPatchInner': {'description': 'true if source is in the inner region of a coadd patch',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'detect_isPrimary': {'description': 'true if source has no children and is in the inner region of a coadd patch and is in the inner region of a coadd tract and is not "detected" in a pseudo-filter (see config.pseudoFilterList)',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'detect_isTractInner': {'description': 'true if source is in the inner region of a coadd tract',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'ext_convolved_ConvolvedFlux_0_3_3_apCorr': {'description': 'aperture correction applied to ext_convolved_ConvolvedFlux_0_3_3',
#   'dtype': dtype('float64'),
#   'unit': None},
#  'ext_convolved_ConvolvedFlux_0_3_3_apCorrSigma': {'description': 'aperture correction applied to ext_convolved_ConvolvedFlux_0_3_3',
#   'dtype': dtype('float64'),
#   'unit': None},
#  'ext_convolved_ConvolvedFlux_0_3_3_flag': {'description': 'General Failure Flag',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'ext_convolved_ConvolvedFlux_0_3_3_flag_apCorr': {'description': 'set if unable to aperture correct ext_convolved_ConvolvedFlux_0_3_3',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'ext_convolved_ConvolvedFlux_0_3_3_flag_apertureTruncated': {'description': 'aperture did not fit within measurement image',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'ext_convolved_ConvolvedFlux_0_3_3_flag_sincCoeffsTruncated': {'description': 'full sinc coefficient image did not fit within measurement image',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'ext_convolved_ConvolvedFlux_0_3_3_flux': {'description': 'flux within 3.300000-pixel aperture',
#   'dtype': dtype('float64'),
#   'unit': Unit("ct")},
#  'ext_convolved_ConvolvedFlux_0_3_3_fluxSigma': {'description': '1-sigma flux uncertainty',
#   'dtype': dtype('float64'),
#   'unit': Unit("ct")},
#  'ext_convolved_ConvolvedFlux_0_4_5_apCorr': {'description': 'aperture correction applied to ext_convolved_ConvolvedFlux_0_4_5',
#   'dtype': dtype('float64'),
#   'unit': None},
#  'ext_convolved_ConvolvedFlux_0_4_5_apCorrSigma': {'description': 'aperture correction applied to ext_convolved_ConvolvedFlux_0_4_5',
#   'dtype': dtype('float64'),
#   'unit': None},
#  'ext_convolved_ConvolvedFlux_0_4_5_flag': {'description': 'General Failure Flag',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'ext_convolved_ConvolvedFlux_0_4_5_flag_apCorr': {'description': 'set if unable to aperture correct ext_convolved_ConvolvedFlux_0_4_5',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'ext_convolved_ConvolvedFlux_0_4_5_flag_apertureTruncated': {'description': 'aperture did not fit within measurement image',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'ext_convolved_ConvolvedFlux_0_4_5_flag_sincCoeffsTruncated': {'description': 'full sinc coefficient image did not fit within measurement image',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'ext_convolved_ConvolvedFlux_0_4_5_flux': {'description': 'flux within 4.500000-pixel aperture',
#   'dtype': dtype('float64'),
#   'unit': Unit("ct")},
#  'ext_convolved_ConvolvedFlux_0_4_5_fluxSigma': {'description': '1-sigma flux uncertainty',
#   'dtype': dtype('float64'),
#   'unit': Unit("ct")},
#  'ext_convolved_ConvolvedFlux_0_6_0_apCorr': {'description': 'aperture correction applied to ext_convolved_ConvolvedFlux_0_6_0',
#   'dtype': dtype('float64'),
#   'unit': None},
#  'ext_convolved_ConvolvedFlux_0_6_0_apCorrSigma': {'description': 'aperture correction applied to ext_convolved_ConvolvedFlux_0_6_0',
#   'dtype': dtype('float64'),
#   'unit': None},
#  'ext_convolved_ConvolvedFlux_0_6_0_flag': {'description': 'General Failure Flag',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'ext_convolved_ConvolvedFlux_0_6_0_flag_apCorr': {'description': 'set if unable to aperture correct ext_convolved_ConvolvedFlux_0_6_0',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'ext_convolved_ConvolvedFlux_0_6_0_flag_apertureTruncated': {'description': 'aperture did not fit within measurement image',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'ext_convolved_ConvolvedFlux_0_6_0_flag_sincCoeffsTruncated': {'description': 'full sinc coefficient image did not fit within measurement image',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'ext_convolved_ConvolvedFlux_0_6_0_flux': {'description': 'flux within 6.000000-pixel aperture',
#   'dtype': dtype('float64'),
#   'unit': Unit("ct")},
#  'ext_convolved_ConvolvedFlux_0_6_0_fluxSigma': {'description': '1-sigma flux uncertainty',
#   'dtype': dtype('float64'),
#   'unit': Unit("ct")},
#  'ext_convolved_ConvolvedFlux_0_deconv': {'description': 'deconvolution required for seeing 3.500000; no measurement made',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'ext_convolved_ConvolvedFlux_0_flag_badCentroid': {'description': 'General Failure Flag',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'ext_convolved_ConvolvedFlux_0_flag_badCentroid_almostNoSecondDerivative': {'description': 'Almost vanishing second derivative',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'ext_convolved_ConvolvedFlux_0_flag_badCentroid_edge': {'description': 'Object too close to edge',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'ext_convolved_ConvolvedFlux_0_flag_badCentroid_noSecondDerivative': {'description': 'Vanishing second derivative',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'ext_convolved_ConvolvedFlux_0_flag_badCentroid_notAtMaximum': {'description': 'Object is not at a maximum',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'ext_convolved_ConvolvedFlux_0_flag_badCentroid_resetToPeak': {'description': 'set if CentroidChecker reset the centroid',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'ext_convolved_ConvolvedFlux_0_kron_apCorr': {'description': 'aperture correction applied to ext_convolved_ConvolvedFlux_0_kron',
#   'dtype': dtype('float64'),
#   'unit': None},
#  'ext_convolved_ConvolvedFlux_0_kron_apCorrSigma': {'description': 'aperture correction applied to ext_convolved_ConvolvedFlux_0_kron',
#   'dtype': dtype('float64'),
#   'unit': None},
#  'ext_convolved_ConvolvedFlux_0_kron_flag': {'description': 'convolved Kron flux failed: seeing 3.500000',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'ext_convolved_ConvolvedFlux_0_kron_flag_apCorr': {'description': 'set if unable to aperture correct ext_convolved_ConvolvedFlux_0_kron',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'ext_convolved_ConvolvedFlux_0_kron_flux': {'description': 'convolved Kron flux: seeing 3.500000',
#   'dtype': dtype('float64'),
#   'unit': Unit("ct")},
#  'ext_convolved_ConvolvedFlux_0_kron_fluxSigma': {'description': '1-sigma flux uncertainty',
#   'dtype': dtype('float64'),
#   'unit': Unit("ct")},
#  'ext_convolved_ConvolvedFlux_1_3_3_apCorr': {'description': 'aperture correction applied to ext_convolved_ConvolvedFlux_1_3_3',
#   'dtype': dtype('float64'),
#   'unit': None},
#  'ext_convolved_ConvolvedFlux_1_3_3_apCorrSigma': {'description': 'aperture correction applied to ext_convolved_ConvolvedFlux_1_3_3',
#   'dtype': dtype('float64'),
#   'unit': None},
#  'ext_convolved_ConvolvedFlux_1_3_3_flag': {'description': 'General Failure Flag',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'ext_convolved_ConvolvedFlux_1_3_3_flag_apCorr': {'description': 'set if unable to aperture correct ext_convolved_ConvolvedFlux_1_3_3',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'ext_convolved_ConvolvedFlux_1_3_3_flag_apertureTruncated': {'description': 'aperture did not fit within measurement image',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'ext_convolved_ConvolvedFlux_1_3_3_flag_sincCoeffsTruncated': {'description': 'full sinc coefficient image did not fit within measurement image',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'ext_convolved_ConvolvedFlux_1_3_3_flux': {'description': 'flux within 3.300000-pixel aperture',
#   'dtype': dtype('float64'),
#   'unit': Unit("ct")},
#  'ext_convolved_ConvolvedFlux_1_3_3_fluxSigma': {'description': '1-sigma flux uncertainty',
#   'dtype': dtype('float64'),
#   'unit': Unit("ct")},
#  'ext_convolved_ConvolvedFlux_1_4_5_apCorr': {'description': 'aperture correction applied to ext_convolved_ConvolvedFlux_1_4_5',
#   'dtype': dtype('float64'),
#   'unit': None},
#  'ext_convolved_ConvolvedFlux_1_4_5_apCorrSigma': {'description': 'aperture correction applied to ext_convolved_ConvolvedFlux_1_4_5',
#   'dtype': dtype('float64'),
#   'unit': None},
#  'ext_convolved_ConvolvedFlux_1_4_5_flag': {'description': 'General Failure Flag',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'ext_convolved_ConvolvedFlux_1_4_5_flag_apCorr': {'description': 'set if unable to aperture correct ext_convolved_ConvolvedFlux_1_4_5',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'ext_convolved_ConvolvedFlux_1_4_5_flag_apertureTruncated': {'description': 'aperture did not fit within measurement image',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'ext_convolved_ConvolvedFlux_1_4_5_flag_sincCoeffsTruncated': {'description': 'full sinc coefficient image did not fit within measurement image',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'ext_convolved_ConvolvedFlux_1_4_5_flux': {'description': 'flux within 4.500000-pixel aperture',
#   'dtype': dtype('float64'),
#   'unit': Unit("ct")},
#  'ext_convolved_ConvolvedFlux_1_4_5_fluxSigma': {'description': '1-sigma flux uncertainty',
#   'dtype': dtype('float64'),
#   'unit': Unit("ct")},
#  'ext_convolved_ConvolvedFlux_1_6_0_apCorr': {'description': 'aperture correction applied to ext_convolved_ConvolvedFlux_1_6_0',
#   'dtype': dtype('float64'),
#   'unit': None},
#  'ext_convolved_ConvolvedFlux_1_6_0_apCorrSigma': {'description': 'aperture correction applied to ext_convolved_ConvolvedFlux_1_6_0',
#   'dtype': dtype('float64'),
#   'unit': None},
#  'ext_convolved_ConvolvedFlux_1_6_0_flag': {'description': 'General Failure Flag',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'ext_convolved_ConvolvedFlux_1_6_0_flag_apCorr': {'description': 'set if unable to aperture correct ext_convolved_ConvolvedFlux_1_6_0',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'ext_convolved_ConvolvedFlux_1_6_0_flag_apertureTruncated': {'description': 'aperture did not fit within measurement image',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'ext_convolved_ConvolvedFlux_1_6_0_flag_sincCoeffsTruncated': {'description': 'full sinc coefficient image did not fit within measurement image',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'ext_convolved_ConvolvedFlux_1_6_0_flux': {'description': 'flux within 6.000000-pixel aperture',
#   'dtype': dtype('float64'),
#   'unit': Unit("ct")},
#  'ext_convolved_ConvolvedFlux_1_6_0_fluxSigma': {'description': '1-sigma flux uncertainty',
#   'dtype': dtype('float64'),
#   'unit': Unit("ct")},
#  'ext_convolved_ConvolvedFlux_1_deconv': {'description': 'deconvolution required for seeing 5.000000; no measurement made',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'ext_convolved_ConvolvedFlux_1_flag_badCentroid': {'description': 'General Failure Flag',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'ext_convolved_ConvolvedFlux_1_flag_badCentroid_almostNoSecondDerivative': {'description': 'Almost vanishing second derivative',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'ext_convolved_ConvolvedFlux_1_flag_badCentroid_edge': {'description': 'Object too close to edge',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'ext_convolved_ConvolvedFlux_1_flag_badCentroid_noSecondDerivative': {'description': 'Vanishing second derivative',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'ext_convolved_ConvolvedFlux_1_flag_badCentroid_notAtMaximum': {'description': 'Object is not at a maximum',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'ext_convolved_ConvolvedFlux_1_flag_badCentroid_resetToPeak': {'description': 'set if CentroidChecker reset the centroid',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'ext_convolved_ConvolvedFlux_1_kron_apCorr': {'description': 'aperture correction applied to ext_convolved_ConvolvedFlux_1_kron',
#   'dtype': dtype('float64'),
#   'unit': None},
#  'ext_convolved_ConvolvedFlux_1_kron_apCorrSigma': {'description': 'aperture correction applied to ext_convolved_ConvolvedFlux_1_kron',
#   'dtype': dtype('float64'),
#   'unit': None},
#  'ext_convolved_ConvolvedFlux_1_kron_flag': {'description': 'convolved Kron flux failed: seeing 5.000000',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'ext_convolved_ConvolvedFlux_1_kron_flag_apCorr': {'description': 'set if unable to aperture correct ext_convolved_ConvolvedFlux_1_kron',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'ext_convolved_ConvolvedFlux_1_kron_flux': {'description': 'convolved Kron flux: seeing 5.000000',
#   'dtype': dtype('float64'),
#   'unit': Unit("ct")},
#  'ext_convolved_ConvolvedFlux_1_kron_fluxSigma': {'description': '1-sigma flux uncertainty',
#   'dtype': dtype('float64'),
#   'unit': Unit("ct")},
#  'ext_convolved_ConvolvedFlux_2_3_3_apCorr': {'description': 'aperture correction applied to ext_convolved_ConvolvedFlux_2_3_3',
#   'dtype': dtype('float64'),
#   'unit': None},
#  'ext_convolved_ConvolvedFlux_2_3_3_apCorrSigma': {'description': 'aperture correction applied to ext_convolved_ConvolvedFlux_2_3_3',
#   'dtype': dtype('float64'),
#   'unit': None},
#  'ext_convolved_ConvolvedFlux_2_3_3_flag': {'description': 'General Failure Flag',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'ext_convolved_ConvolvedFlux_2_3_3_flag_apCorr': {'description': 'set if unable to aperture correct ext_convolved_ConvolvedFlux_2_3_3',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'ext_convolved_ConvolvedFlux_2_3_3_flag_apertureTruncated': {'description': 'aperture did not fit within measurement image',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'ext_convolved_ConvolvedFlux_2_3_3_flag_sincCoeffsTruncated': {'description': 'full sinc coefficient image did not fit within measurement image',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'ext_convolved_ConvolvedFlux_2_3_3_flux': {'description': 'flux within 3.300000-pixel aperture',
#   'dtype': dtype('float64'),
#   'unit': Unit("ct")},
#  'ext_convolved_ConvolvedFlux_2_3_3_fluxSigma': {'description': '1-sigma flux uncertainty',
#   'dtype': dtype('float64'),
#   'unit': Unit("ct")},
#  'ext_convolved_ConvolvedFlux_2_4_5_apCorr': {'description': 'aperture correction applied to ext_convolved_ConvolvedFlux_2_4_5',
#   'dtype': dtype('float64'),
#   'unit': None},
#  'ext_convolved_ConvolvedFlux_2_4_5_apCorrSigma': {'description': 'aperture correction applied to ext_convolved_ConvolvedFlux_2_4_5',
#   'dtype': dtype('float64'),
#   'unit': None},
#  'ext_convolved_ConvolvedFlux_2_4_5_flag': {'description': 'General Failure Flag',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'ext_convolved_ConvolvedFlux_2_4_5_flag_apCorr': {'description': 'set if unable to aperture correct ext_convolved_ConvolvedFlux_2_4_5',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'ext_convolved_ConvolvedFlux_2_4_5_flag_apertureTruncated': {'description': 'aperture did not fit within measurement image',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'ext_convolved_ConvolvedFlux_2_4_5_flag_sincCoeffsTruncated': {'description': 'full sinc coefficient image did not fit within measurement image',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'ext_convolved_ConvolvedFlux_2_4_5_flux': {'description': 'flux within 4.500000-pixel aperture',
#   'dtype': dtype('float64'),
#   'unit': Unit("ct")},
#  'ext_convolved_ConvolvedFlux_2_4_5_fluxSigma': {'description': '1-sigma flux uncertainty',
#   'dtype': dtype('float64'),
#   'unit': Unit("ct")},
#  'ext_convolved_ConvolvedFlux_2_6_0_apCorr': {'description': 'aperture correction applied to ext_convolved_ConvolvedFlux_2_6_0',
#   'dtype': dtype('float64'),
#   'unit': None},
#  'ext_convolved_ConvolvedFlux_2_6_0_apCorrSigma': {'description': 'aperture correction applied to ext_convolved_ConvolvedFlux_2_6_0',
#   'dtype': dtype('float64'),
#   'unit': None},
#  'ext_convolved_ConvolvedFlux_2_6_0_flag': {'description': 'General Failure Flag',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'ext_convolved_ConvolvedFlux_2_6_0_flag_apCorr': {'description': 'set if unable to aperture correct ext_convolved_ConvolvedFlux_2_6_0',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'ext_convolved_ConvolvedFlux_2_6_0_flag_apertureTruncated': {'description': 'aperture did not fit within measurement image',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'ext_convolved_ConvolvedFlux_2_6_0_flag_sincCoeffsTruncated': {'description': 'full sinc coefficient image did not fit within measurement image',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'ext_convolved_ConvolvedFlux_2_6_0_flux': {'description': 'flux within 6.000000-pixel aperture',
#   'dtype': dtype('float64'),
#   'unit': Unit("ct")},
#  'ext_convolved_ConvolvedFlux_2_6_0_fluxSigma': {'description': '1-sigma flux uncertainty',
#   'dtype': dtype('float64'),
#   'unit': Unit("ct")},
#  'ext_convolved_ConvolvedFlux_2_deconv': {'description': 'deconvolution required for seeing 6.500000; no measurement made',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'ext_convolved_ConvolvedFlux_2_flag_badCentroid': {'description': 'General Failure Flag',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'ext_convolved_ConvolvedFlux_2_flag_badCentroid_almostNoSecondDerivative': {'description': 'Almost vanishing second derivative',
#   'dtype': dtype('bool'),
#   'unit': None},
# ...
#   'unit': None},
#  'slot_ModelFlux_dev_flag': {'description': 'flag set when the flux for the de Vaucouleur flux failed',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'slot_ModelFlux_dev_flag_apCorr': {'description': 'set if unable to aperture correct modelfit_CModel_dev',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'slot_ModelFlux_dev_flag_maxIter': {'description': 'the optimizer hit the maximum number of iterations and did not converge',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'slot_ModelFlux_dev_flag_numericError': {'description': 'numerical underflow or overflow in model evaluation; usually this means the prior was insufficient to regularize the fit, or all pixel values were zero.',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'slot_ModelFlux_dev_flag_trSmall': {'description': 'the optimizer converged because the trust radius became too small; this is a less-secure result than when the gradient is below the threshold, but usually not a problem',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'slot_ModelFlux_dev_flux': {'description': 'flux from the de Vaucouleur fit',
#   'dtype': dtype('float64'),
#   'unit': Unit("ct")},
#  'slot_ModelFlux_dev_fluxSigma': {'description': 'flux uncertainty from the de Vaucouleur fit',
#   'dtype': dtype('float64'),
#   'unit': Unit("ct")},
#  'slot_ModelFlux_dev_flux_inner': {'description': 'flux within the fit region, with no extrapolation',
#   'dtype': dtype('float64'),
#   'unit': None},
#  'slot_ModelFlux_dev_nIter': {'description': 'Number of total iterations in stage',
#   'dtype': dtype('int32'),
#   'unit': None},
#  'slot_ModelFlux_dev_nonlinear_0': {'description': 'nonlinear parameters for the de Vaucouleur fit',
#   'dtype': dtype('float64'),
#   'unit': None},
#  'slot_ModelFlux_dev_nonlinear_1': {'description': 'nonlinear parameters for the de Vaucouleur fit',
#   'dtype': dtype('float64'),
#   'unit': None},
#  'slot_ModelFlux_dev_nonlinear_2': {'description': 'nonlinear parameters for the de Vaucouleur fit',
#   'dtype': dtype('float64'),
#   'unit': None},
#  'slot_ModelFlux_dev_objective': {'description': '-ln(likelihood*prior) at best-fit point for the de Vaucouleur fit',
#   'dtype': dtype('float64'),
#   'unit': None},
#  'slot_ModelFlux_dev_time': {'description': 'Time spent in stage',
#   'dtype': dtype('float64'),
#   'unit': Unit("s")},
#  'slot_ModelFlux_ellipse_xx': {'description': 'fracDev-weighted average of exp.ellipse and dev.ellipse',
#   'dtype': dtype('float64'),
#   'unit': Unit("pix2")},
#  'slot_ModelFlux_ellipse_xy': {'description': 'fracDev-weighted average of exp.ellipse and dev.ellipse',
#   'dtype': dtype('float64'),
#   'unit': Unit("pix2")},
#  'slot_ModelFlux_ellipse_yy': {'description': 'fracDev-weighted average of exp.ellipse and dev.ellipse',
#   'dtype': dtype('float64'),
#   'unit': Unit("pix2")},
#  'slot_ModelFlux_exp_apCorr': {'description': 'aperture correction applied to modelfit_CModel_exp',
#   'dtype': dtype('float64'),
#   'unit': None},
#  'slot_ModelFlux_exp_apCorrSigma': {'description': 'aperture correction applied to modelfit_CModel_exp',
#   'dtype': dtype('float64'),
#   'unit': None},
#  'slot_ModelFlux_exp_ellipse_xx': {'description': 'half-light ellipse of the exponential fit',
#   'dtype': dtype('float64'),
#   'unit': Unit("pix2")},
#  'slot_ModelFlux_exp_ellipse_xy': {'description': 'half-light ellipse of the exponential fit',
#   'dtype': dtype('float64'),
#   'unit': Unit("pix2")},
#  'slot_ModelFlux_exp_ellipse_yy': {'description': 'half-light ellipse of the exponential fit',
#   'dtype': dtype('float64'),
#   'unit': Unit("pix2")},
#  'slot_ModelFlux_exp_fixed_0': {'description': 'fixed parameters for the exponential fit',
#   'dtype': dtype('float64'),
#   'unit': None},
#  'slot_ModelFlux_exp_fixed_1': {'description': 'fixed parameters for the exponential fit',
#   'dtype': dtype('float64'),
#   'unit': None},
#  'slot_ModelFlux_exp_flag': {'description': 'flag set when the flux for the exponential flux failed',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'slot_ModelFlux_exp_flag_apCorr': {'description': 'set if unable to aperture correct modelfit_CModel_exp',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'slot_ModelFlux_exp_flag_maxIter': {'description': 'the optimizer hit the maximum number of iterations and did not converge',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'slot_ModelFlux_exp_flag_numericError': {'description': 'numerical underflow or overflow in model evaluation; usually this means the prior was insufficient to regularize the fit, or all pixel values were zero.',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'slot_ModelFlux_exp_flag_trSmall': {'description': 'the optimizer converged because the trust radius became too small; this is a less-secure result than when the gradient is below the threshold, but usually not a problem',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'slot_ModelFlux_exp_flux': {'description': 'flux from the exponential fit',
#   'dtype': dtype('float64'),
#   'unit': Unit("ct")},
#  'slot_ModelFlux_exp_fluxSigma': {'description': 'flux uncertainty from the exponential fit',
#   'dtype': dtype('float64'),
#   'unit': Unit("ct")},
#  'slot_ModelFlux_exp_flux_inner': {'description': 'flux within the fit region, with no extrapolation',
#   'dtype': dtype('float64'),
#   'unit': None},
#  'slot_ModelFlux_exp_nIter': {'description': 'Number of total iterations in stage',
#   'dtype': dtype('int32'),
#   'unit': None},
#  'slot_ModelFlux_exp_nonlinear_0': {'description': 'nonlinear parameters for the exponential fit',
#   'dtype': dtype('float64'),
#   'unit': None},
#  'slot_ModelFlux_exp_nonlinear_1': {'description': 'nonlinear parameters for the exponential fit',
#   'dtype': dtype('float64'),
#   'unit': None},
#  'slot_ModelFlux_exp_nonlinear_2': {'description': 'nonlinear parameters for the exponential fit',
#   'dtype': dtype('float64'),
#   'unit': None},
#  'slot_ModelFlux_exp_objective': {'description': '-ln(likelihood*prior) at best-fit point for the exponential fit',
#   'dtype': dtype('float64'),
#   'unit': None},
#  'slot_ModelFlux_exp_time': {'description': 'Time spent in stage',
#   'dtype': dtype('float64'),
#   'unit': Unit("s")},
#  'slot_ModelFlux_flag': {'description': 'flag set if the final cmodel fit (or any previous fit) failed',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'slot_ModelFlux_flag_apCorr': {'description': 'set if unable to aperture correct modelfit_CModel',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'slot_ModelFlux_flag_badCentroid': {'description': "input centroid was not within the fit region (probably because it''s not within the Footprint)",
#   'dtype': dtype('bool'),
#   'unit': None},
#  'slot_ModelFlux_flag_noShape': {'description': 'the shape slot needed to initialize the parameters failed or was not defined',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'slot_ModelFlux_flag_noShapeletPsf': {'description': 'the multishapelet fit to the PSF model did not succeed',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'slot_ModelFlux_flag_region_maxArea': {'description': 'number of pixels in fit region exceeded the region.maxArea value',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'slot_ModelFlux_flag_region_maxBadPixelFraction': {'description': 'the fraction of bad/clipped pixels in the fit region exceeded region.maxBadPixelFraction',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'slot_ModelFlux_flags_region_usedFootprintArea': {'description': 'the pixel region for the initial fit was defined by the area of the Footprint',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'slot_ModelFlux_flags_region_usedInitialEllipseMax': {'description': 'the pixel region for the final fit was set to the upper bound defined by the initial fit',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'slot_ModelFlux_flags_region_usedInitialEllipseMin': {'description': 'the pixel region for the final fit was set to the lower bound defined by the initial fit',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'slot_ModelFlux_flags_region_usedPsfArea': {'description': 'the pixel region for the initial fit was set to a fixed factor of the PSF area',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'slot_ModelFlux_flags_smallShape': {'description': 'initial parameter guess resulted in negative radius; used minimum of 0.100000 pixels instead.',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'slot_ModelFlux_flux': {'description': 'flux from the final cmodel fit',
#   'dtype': dtype('float64'),
#   'unit': None},
#  'slot_ModelFlux_fluxSigma': {'description': 'flux uncertainty from the final cmodel fit',
#   'dtype': dtype('float64'),
#   'unit': None},
#  'slot_ModelFlux_flux_inner': {'description': 'flux within the fit region, with no extrapolation',
#   'dtype': dtype('float64'),
#   'unit': None},
#  'slot_ModelFlux_fracDev': {'description': 'fraction of flux in de Vaucouleur component',
#   'dtype': dtype('float64'),
#   'unit': None},
#  'slot_ModelFlux_initial_apCorr': {'description': 'aperture correction applied to modelfit_CModel_initial',
#   'dtype': dtype('float64'),
#   'unit': None},
#  'slot_ModelFlux_initial_apCorrSigma': {'description': 'aperture correction applied to modelfit_CModel_initial',
#   'dtype': dtype('float64'),
#   'unit': None},
#  'slot_ModelFlux_initial_ellipse_xx': {'description': 'half-light ellipse of the initial fit',
#   'dtype': dtype('float64'),
#   'unit': Unit("pix2")},
#  'slot_ModelFlux_initial_ellipse_xy': {'description': 'half-light ellipse of the initial fit',
#   'dtype': dtype('float64'),
#   'unit': Unit("pix2")},
#  'slot_ModelFlux_initial_ellipse_yy': {'description': 'half-light ellipse of the initial fit',
#   'dtype': dtype('float64'),
#   'unit': Unit("pix2")},
#  'slot_ModelFlux_initial_fixed_0': {'description': 'fixed parameters for the initial fit',
#   'dtype': dtype('float64'),
#   'unit': None},
#  'slot_ModelFlux_initial_fixed_1': {'description': 'fixed parameters for the initial fit',
#   'dtype': dtype('float64'),
#   'unit': None},
#  'slot_ModelFlux_initial_flag': {'description': 'flag set when the flux for the initial flux failed',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'slot_ModelFlux_initial_flag_apCorr': {'description': 'set if unable to aperture correct modelfit_CModel_initial',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'slot_ModelFlux_initial_flag_maxIter': {'description': 'the optimizer hit the maximum number of iterations and did not converge',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'slot_ModelFlux_initial_flag_numericError': {'description': 'numerical underflow or overflow in model evaluation; usually this means the prior was insufficient to regularize the fit, or all pixel values were zero.',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'slot_ModelFlux_initial_flag_trSmall': {'description': 'the optimizer converged because the trust radius became too small; this is a less-secure result than when the gradient is below the threshold, but usually not a problem',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'slot_ModelFlux_initial_flux': {'description': 'flux from the initial fit',
#   'dtype': dtype('float64'),
#   'unit': Unit("ct")},
#  'slot_ModelFlux_initial_fluxSigma': {'description': 'flux uncertainty from the initial fit',
#   'dtype': dtype('float64'),
#   'unit': Unit("ct")},
#  'slot_ModelFlux_initial_flux_inner': {'description': 'flux within the fit region, with no extrapolation',
#   'dtype': dtype('float64'),
#   'unit': None},
#  'slot_ModelFlux_initial_nIter': {'description': 'Number of total iterations in stage',
#   'dtype': dtype('int32'),
#   'unit': None},
#  'slot_ModelFlux_initial_nonlinear_0': {'description': 'nonlinear parameters for the initial fit',
#   'dtype': dtype('float64'),
#   'unit': None},
#  'slot_ModelFlux_initial_nonlinear_1': {'description': 'nonlinear parameters for the initial fit',
#   'dtype': dtype('float64'),
#   'unit': None},
#  'slot_ModelFlux_initial_nonlinear_2': {'description': 'nonlinear parameters for the initial fit',
#   'dtype': dtype('float64'),
#   'unit': None},
#  'slot_ModelFlux_initial_objective': {'description': '-ln(likelihood*prior) at best-fit point for the initial fit',
#   'dtype': dtype('float64'),
#   'unit': None},
#  'slot_ModelFlux_initial_time': {'description': 'Time spent in stage',
#   'dtype': dtype('float64'),
#   'unit': Unit("s")},
#  'slot_ModelFlux_objective': {'description': '-ln(likelihood) (chi^2) in cmodel fit',
#   'dtype': dtype('float64'),
#   'unit': None},
#  'slot_ModelFlux_region_final_ellipse_xx': {'description': 'ellipse used to set the pixel region for the final fit (before applying bad pixel mask)',
#   'dtype': dtype('float64'),
#   'unit': Unit("pix2")},
#  'slot_ModelFlux_region_final_ellipse_xy': {'description': 'ellipse used to set the pixel region for the final fit (before applying bad pixel mask)',
#   'dtype': dtype('float64'),
#   'unit': Unit("pix2")},
#  'slot_ModelFlux_region_final_ellipse_yy': {'description': 'ellipse used to set the pixel region for the final fit (before applying bad pixel mask)',
#   'dtype': dtype('float64'),
#   'unit': Unit("pix2")},
#  'slot_ModelFlux_region_initial_ellipse_xx': {'description': 'ellipse used to set the pixel region for the initial fit (before applying bad pixel mask)',
#   'dtype': dtype('float64'),
#   'unit': Unit("pix2")},
#  'slot_ModelFlux_region_initial_ellipse_xy': {'description': 'ellipse used to set the pixel region for the initial fit (before applying bad pixel mask)',
#   'dtype': dtype('float64'),
#   'unit': Unit("pix2")},
#  'slot_ModelFlux_region_initial_ellipse_yy': {'description': 'ellipse used to set the pixel region for the initial fit (before applying bad pixel mask)',
#   'dtype': dtype('float64'),
#   'unit': Unit("pix2")},
#  'slot_PsfFlux_apCorr': {'description': 'aperture correction applied to base_PsfFlux',
#   'dtype': dtype('float64'),
#   'unit': None},
#  'slot_PsfFlux_apCorrSigma': {'description': 'aperture correction applied to base_PsfFlux',
#   'dtype': dtype('float64'),
#   'unit': None},
#  'slot_PsfFlux_flag': {'description': 'General Failure Flag',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'slot_PsfFlux_flag_apCorr': {'description': 'set if unable to aperture correct base_PsfFlux',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'slot_PsfFlux_flag_edge': {'description': 'object was too close to the edge of the image to use the full PSF model',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'slot_PsfFlux_flag_noGoodPixels': {'description': 'not enough non-rejected pixels in data to attempt the fit',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'slot_PsfFlux_flux': {'description': 'flux derived from linear least-squares fit of PSF model',
#   'dtype': dtype('float64'),
#   'unit': Unit("ct")},
#  'slot_PsfFlux_fluxSigma': {'description': '1-sigma flux uncertainty',
#   'dtype': dtype('float64'),
#   'unit': Unit("ct")},
#  'slot_PsfShape_xx': {'description': 'adaptive moments of the PSF model at the object position',
#   'dtype': dtype('float64'),
#   'unit': Unit("pix2")},
#  'slot_PsfShape_xy': {'description': 'adaptive moments of the PSF model at the object position',
#   'dtype': dtype('float64'),
#   'unit': Unit("pix2")},
#  'slot_PsfShape_yy': {'description': 'adaptive moments of the PSF model at the object position',
#   'dtype': dtype('float64'),
#   'unit': Unit("pix2")},
#  'slot_Shape_flag': {'description': 'general failure flag, set if anything went wrong',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'slot_Shape_flag_no_pixels': {'description': 'no pixels to measure',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'slot_Shape_flag_not_contained': {'description': 'center not contained in footprint bounding box',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'slot_Shape_flag_parent_source': {'description': 'parent source, ignored',
#   'dtype': dtype('bool'),
#   'unit': None},
#  'slot_Shape_x': {'description': 'HSM Centroid',
#   'dtype': dtype('float64'),
#   'unit': Unit("pix")},
#  'slot_Shape_xx': {'description': 'HSM moments',
#   'dtype': dtype('float64'),
#   'unit': Unit("pix2")},
#  'slot_Shape_xy': {'description': 'HSM moments',
#   'dtype': dtype('float64'),
#   'unit': Unit("pix2")},
#  'slot_Shape_y': {'description': 'HSM Centroid',
#   'dtype': dtype('float64'),
#   'unit': Unit("pix")},
#  'slot_Shape_yy': {'description': 'HSM moments',
#   'dtype': dtype('float64'),
#   'unit': Unit("pix2")}}

# %%
from astropy.table import Table

# %%
import numpy as np
# Out:
# IndexErrorTraceback (most recent call last)
# <ipython-input-127-55b3d3d24a82> in <module>()
#       1 import numpy as np
# ----> 2 np.array(t)[0]
#
# IndexError: too many indices for array

# %%
dd = dict(schema)

# %%
cc = dd['base_Blendedness_abs_child_xx']

# %%
sch.getSchema()
# Out:
# Schema(
#     (Field['L'](name="id", doc="unique ID"), Key<L>(offset=0, nElements=1)),
#     (Field['Angle'](name="coord_ra", doc="position in ra/dec"), Key<Angle>(offset=8, nElements=1)),
#     (Field['Angle'](name="coord_dec", doc="position in ra/dec"), Key<Angle>(offset=16, nElements=1)),
#     (Field['L'](name="parent", doc="unique ID of parent source"), Key<L>(offset=24, nElements=1)),
#     (Field['Flag'](name="merge_footprint_i", doc="Detection footprint overlapped with a detection from filter i"), Key['Flag'](offset=32, bit=0)),
#     (Field['Flag'](name="merge_footprint_r", doc="Detection footprint overlapped with a detection from filter r"), Key['Flag'](offset=32, bit=1)),
#     (Field['Flag'](name="merge_footprint_z", doc="Detection footprint overlapped with a detection from filter z"), Key['Flag'](offset=32, bit=2)),
#     (Field['Flag'](name="merge_footprint_g", doc="Detection footprint overlapped with a detection from filter g"), Key['Flag'](offset=32, bit=3)),
#     (Field['Flag'](name="merge_footprint_u", doc="Detection footprint overlapped with a detection from filter u"), Key['Flag'](offset=32, bit=4)),
#     (Field['Flag'](name="merge_footprint_sky", doc="Detection footprint overlapped with a detection from filter sky"), Key['Flag'](offset=32, bit=5)),
#     (Field['Flag'](name="merge_peak_i", doc="Peak detected in filter i"), Key['Flag'](offset=32, bit=6)),
#     (Field['Flag'](name="merge_peak_r", doc="Peak detected in filter r"), Key['Flag'](offset=32, bit=7)),
#     (Field['Flag'](name="merge_peak_z", doc="Peak detected in filter z"), Key['Flag'](offset=32, bit=8)),
#     (Field['Flag'](name="merge_peak_g", doc="Peak detected in filter g"), Key['Flag'](offset=32, bit=9)),
#     (Field['Flag'](name="merge_peak_u", doc="Peak detected in filter u"), Key['Flag'](offset=32, bit=10)),
#     (Field['Flag'](name="merge_peak_sky", doc="Peak detected in filter sky"), Key['Flag'](offset=32, bit=11)),
#     (Field['I'](name="deblend_nChild", doc="Number of children this object has (defaults to 0)"), Key<I>(offset=40, nElements=1)),
#     (Field['Flag'](name="deblend_deblendedAsPsf", doc="Deblender thought this source looked like a PSF"), Key['Flag'](offset=32, bit=12)),
#     (Field['D'](name="deblend_psfCenter_x", doc="If deblended-as-psf, the PSF centroid", units="pixel"), Key<D>(offset=48, nElements=1)),
#     (Field['D'](name="deblend_psfCenter_y", doc="If deblended-as-psf, the PSF centroid", units="pixel"), Key<D>(offset=56, nElements=1)),
#     (Field['D'](name="deblend_psfFlux", doc="If deblended-as-psf, the PSF flux"), Key<D>(offset=64, nElements=1)),
#     (Field['Flag'](name="deblend_tooManyPeaks", doc="Source had too many peaks; only the brightest were included"), Key['Flag'](offset=32, bit=13)),
#     (Field['Flag'](name="deblend_parentTooBig", doc="Parent footprint covered too many pixels"), Key['Flag'](offset=32, bit=14)),
#     (Field['Flag'](name="deblend_masked", doc="Parent footprint was predominantly masked"), Key['Flag'](offset=32, bit=15)),
#     (Field['Flag'](name="deblend_skipped", doc="Deblender skipped this source"), Key['Flag'](offset=32, bit=16)),
#     (Field['Flag'](name="deblend_rampedTemplate", doc="This source was near an image edge and the deblender used "ramp" edge-handling."), Key['Flag'](offset=32, bit=17)),
#     (Field['Flag'](name="deblend_patchedTemplate", doc="This source was near an image edge and the deblender used "patched" edge-handling."), Key['Flag'](offset=32, bit=18)),
#     (Field['Flag'](name="deblend_hasStrayFlux", doc="This source was assigned some stray flux"), Key['Flag'](offset=32, bit=19)),
#     (Field['D'](name="base_GaussianCentroid_x", doc="centroid from Gaussian Centroid algorithm", units="pixel"), Key<D>(offset=72, nElements=1)),
#     (Field['D'](name="base_GaussianCentroid_y", doc="centroid from Gaussian Centroid algorithm", units="pixel"), Key<D>(offset=80, nElements=1)),
#     (Field['Flag'](name="base_GaussianCentroid_flag", doc="General Failure Flag"), Key['Flag'](offset=32, bit=20)),
#     (Field['Flag'](name="base_GaussianCentroid_flag_noPeak", doc="Fitted Centroid has a negative peak"), Key['Flag'](offset=32, bit=21)),
#     (Field['Flag'](name="base_GaussianCentroid_flag_resetToPeak", doc="set if CentroidChecker reset the centroid"), Key['Flag'](offset=32, bit=22)),
#     (Field['D'](name="base_NaiveCentroid_x", doc="centroid from Naive Centroid algorithm", units="pixel"), Key<D>(offset=88, nElements=1)),
#     (Field['D'](name="base_NaiveCentroid_y", doc="centroid from Naive Centroid algorithm", units="pixel"), Key<D>(offset=96, nElements=1)),
#     (Field['Flag'](name="base_NaiveCentroid_flag", doc="General Failure Flag"), Key['Flag'](offset=32, bit=23)),
#     (Field['Flag'](name="base_NaiveCentroid_flag_noCounts", doc="Object to be centroided has no counts"), Key['Flag'](offset=32, bit=24)),
#     (Field['Flag'](name="base_NaiveCentroid_flag_edge", doc="Object too close to edge"), Key['Flag'](offset=32, bit=25)),
#     (Field['Flag'](name="base_NaiveCentroid_flag_resetToPeak", doc="set if CentroidChecker reset the centroid"), Key['Flag'](offset=32, bit=26)),
#     (Field['D'](name="base_SdssCentroid_x", doc="centroid from Sdss Centroid algorithm", units="pixel"), Key<D>(offset=104, nElements=1)),
#     (Field['D'](name="base_SdssCentroid_y", doc="centroid from Sdss Centroid algorithm", units="pixel"), Key<D>(offset=112, nElements=1)),
#     (Field['F'](name="base_SdssCentroid_xSigma", doc="1-sigma uncertainty on x position", units="pixel"), Key<F>(offset=120, nElements=1)),
#     (Field['F'](name="base_SdssCentroid_ySigma", doc="1-sigma uncertainty on y position", units="pixel"), Key<F>(offset=124, nElements=1)),
#     (Field['Flag'](name="base_SdssCentroid_flag", doc="General Failure Flag"), Key['Flag'](offset=32, bit=27)),
#     (Field['Flag'](name="base_SdssCentroid_flag_edge", doc="Object too close to edge"), Key['Flag'](offset=32, bit=28)),
#     (Field['Flag'](name="base_SdssCentroid_flag_noSecondDerivative", doc="Vanishing second derivative"), Key['Flag'](offset=32, bit=29)),
#     (Field['Flag'](name="base_SdssCentroid_flag_almostNoSecondDerivative", doc="Almost vanishing second derivative"), Key['Flag'](offset=32, bit=30)),
#     (Field['Flag'](name="base_SdssCentroid_flag_notAtMaximum", doc="Object is not at a maximum"), Key['Flag'](offset=32, bit=31)),
#     (Field['Flag'](name="base_SdssCentroid_flag_resetToPeak", doc="set if CentroidChecker reset the centroid"), Key['Flag'](offset=32, bit=32)),
#     (Field['D'](name="base_Blendedness_old", doc="blendedness from dot products: (child.dot(parent)/child.dot(child) - 1)"), Key<D>(offset=128, nElements=1)),
#     (Field['D'](name="base_Blendedness_raw_flux", doc="measure of how flux is affected by neighbors: (1 - flux.child/flux.parent)"), Key<D>(offset=136, nElements=1)),
#     (Field['D'](name="base_Blendedness_raw_flux_child", doc="flux of the child, measured with a Gaussian weight matched to the child", units="count"), Key<D>(offset=144, nElements=1)),
#     (Field['D'](name="base_Blendedness_raw_flux_parent", doc="flux of the parent, measured with a Gaussian weight matched to the child", units="count"), Key<D>(offset=152, nElements=1)),
#     (Field['D'](name="base_Blendedness_abs_flux", doc="measure of how flux is affected by neighbors: (1 - flux.child/flux.parent)"), Key<D>(offset=160, nElements=1)),
#     (Field['D'](name="base_Blendedness_abs_flux_child", doc="flux of the child, measured with a Gaussian weight matched to the child", units="count"), Key<D>(offset=168, nElements=1)),
#     (Field['D'](name="base_Blendedness_abs_flux_parent", doc="flux of the parent, measured with a Gaussian weight matched to the child", units="count"), Key<D>(offset=176, nElements=1)),
#     (Field['D'](name="base_Blendedness_raw_child_xx", doc="shape of the child, measured with a Gaussian weight matched to the child", units="pixel^2"), Key<D>(offset=184, nElements=1)),
#     (Field['D'](name="base_Blendedness_raw_child_yy", doc="shape of the child, measured with a Gaussian weight matched to the child", units="pixel^2"), Key<D>(offset=192, nElements=1)),
#     (Field['D'](name="base_Blendedness_raw_child_xy", doc="shape of the child, measured with a Gaussian weight matched to the child", units="pixel^2"), Key<D>(offset=200, nElements=1)),
#     (Field['D'](name="base_Blendedness_raw_parent_xx", doc="shape of the parent, measured with a Gaussian weight matched to the child", units="pixel^2"), Key<D>(offset=208, nElements=1)),
#     (Field['D'](name="base_Blendedness_raw_parent_yy", doc="shape of the parent, measured with a Gaussian weight matched to the child", units="pixel^2"), Key<D>(offset=216, nElements=1)),
#     (Field['D'](name="base_Blendedness_raw_parent_xy", doc="shape of the parent, measured with a Gaussian weight matched to the child", units="pixel^2"), Key<D>(offset=224, nElements=1)),
#     (Field['D'](name="base_Blendedness_abs_child_xx", doc="shape of the child, measured with a Gaussian weight matched to the child", units="pixel^2"), Key<D>(offset=232, nElements=1)),
#     (Field['D'](name="base_Blendedness_abs_child_yy", doc="shape of the child, measured with a Gaussian weight matched to the child", units="pixel^2"), Key<D>(offset=240, nElements=1)),
#     (Field['D'](name="base_Blendedness_abs_child_xy", doc="shape of the child, measured with a Gaussian weight matched to the child", units="pixel^2"), Key<D>(offset=248, nElements=1)),
#     (Field['D'](name="base_Blendedness_abs_parent_xx", doc="shape of the parent, measured with a Gaussian weight matched to the child", units="pixel^2"), Key<D>(offset=256, nElements=1)),
#     (Field['D'](name="base_Blendedness_abs_parent_yy", doc="shape of the parent, measured with a Gaussian weight matched to the child", units="pixel^2"), Key<D>(offset=264, nElements=1)),
#     (Field['D'](name="base_Blendedness_abs_parent_xy", doc="shape of the parent, measured with a Gaussian weight matched to the child", units="pixel^2"), Key<D>(offset=272, nElements=1)),
#     (Field['Flag'](name="base_Blendedness_flag", doc="General Failure Flag"), Key['Flag'](offset=32, bit=33)),
#     (Field['Flag'](name="base_Blendedness_flag_noCentroid", doc="Object has no centroid"), Key['Flag'](offset=32, bit=34)),
#     (Field['Flag'](name="base_Blendedness_flag_noShape", doc="Object has no shape"), Key['Flag'](offset=32, bit=35)),
#     (Field['Flag'](name="base_InputCount_flag", doc="Set for any fatal failure"), Key['Flag'](offset=32, bit=36)),
#     (Field['I'](name="base_InputCount_value", doc="Number of images contributing at center, not including anyclipping"), Key<I>(offset=280, nElements=1)),
#     (Field['Flag'](name="base_InputCount_flag_noInputs", doc="No coadd inputs available"), Key['Flag'](offset=32, bit=37)),
#     (Field['D'](name="base_SdssShape_xx", doc="elliptical Gaussian adaptive moments", units="pixel^2"), Key<D>(offset=288, nElements=1)),
#     (Field['D'](name="base_SdssShape_yy", doc="elliptical Gaussian adaptive moments", units="pixel^2"), Key<D>(offset=296, nElements=1)),
#     (Field['D'](name="base_SdssShape_xy", doc="elliptical Gaussian adaptive moments", units="pixel^2"), Key<D>(offset=304, nElements=1)),
#     (Field['F'](name="base_SdssShape_xxSigma", doc="1-sigma uncertainty on xx moment", units="pixel^2"), Key<F>(offset=312, nElements=1)),
#     (Field['F'](name="base_SdssShape_yySigma", doc="1-sigma uncertainty on yy moment", units="pixel^2"), Key<F>(offset=316, nElements=1)),
#     (Field['F'](name="base_SdssShape_xySigma", doc="1-sigma uncertainty on xy moment", units="pixel^2"), Key<F>(offset=320, nElements=1)),
#     (Field['D'](name="base_SdssShape_x", doc="elliptical Gaussian adaptive moments", units="pixel"), Key<D>(offset=328, nElements=1)),
#     (Field['D'](name="base_SdssShape_y", doc="elliptical Gaussian adaptive moments", units="pixel"), Key<D>(offset=336, nElements=1)),
#     (Field['D'](name="base_SdssShape_flux", doc="elliptical Gaussian adaptive moments", units="count"), Key<D>(offset=344, nElements=1)),
#     (Field['D'](name="base_SdssShape_fluxSigma", doc="1-sigma flux uncertainty", units="count"), Key<D>(offset=352, nElements=1)),
#     (Field['D'](name="base_SdssShape_psf_xx", doc="adaptive moments of the PSF model at the object position", units="pixel^2"), Key<D>(offset=360, nElements=1)),
#     (Field['D'](name="base_SdssShape_psf_yy", doc="adaptive moments of the PSF model at the object position", units="pixel^2"), Key<D>(offset=368, nElements=1)),
#     (Field['D'](name="base_SdssShape_psf_xy", doc="adaptive moments of the PSF model at the object position", units="pixel^2"), Key<D>(offset=376, nElements=1)),
#     (Field['F'](name="base_SdssShape_flux_xx_Cov", doc="uncertainty covariance between base_SdssShape_flux and base_SdssShape_xx", units="count*pixel^2"), Key<F>(offset=384, nElements=1)),
#     (Field['F'](name="base_SdssShape_flux_yy_Cov", doc="uncertainty covariance between base_SdssShape_flux and base_SdssShape_yy", units="count*pixel^2"), Key<F>(offset=388, nElements=1)),
#     (Field['F'](name="base_SdssShape_flux_xy_Cov", doc="uncertainty covariance between base_SdssShape_flux and base_SdssShape_xy", units="count*pixel^2"), Key<F>(offset=392, nElements=1)),
#     (Field['Flag'](name="base_SdssShape_flag", doc="General Failure Flag"), Key['Flag'](offset=32, bit=38)),
#     (Field['Flag'](name="base_SdssShape_flag_unweightedBad", doc="Both weighted and unweighted moments were invalid"), Key['Flag'](offset=32, bit=39)),
#     (Field['Flag'](name="base_SdssShape_flag_unweighted", doc="Weighted moments converged to an invalid value; using unweighted moments"), Key['Flag'](offset=32, bit=40)),
#     (Field['Flag'](name="base_SdssShape_flag_shift", doc="centroid shifted by more than the maximum allowed amount"), Key['Flag'](offset=32, bit=41)),
#     (Field['Flag'](name="base_SdssShape_flag_maxIter", doc="Too many iterations in adaptive moments"), Key['Flag'](offset=32, bit=42)),
#     (Field['Flag'](name="base_SdssShape_flag_psf", doc="Failure in measuring PSF model shape"), Key['Flag'](offset=32, bit=43)),
#     (Field['D'](name="ext_shapeHSM_HsmPsfMoments_x", doc="HSM Centroid", units="pixel"), Key<D>(offset=400, nElements=1)),
#     (Field['D'](name="ext_shapeHSM_HsmPsfMoments_y", doc="HSM Centroid", units="pixel"), Key<D>(offset=408, nElements=1)),
#     (Field['D'](name="ext_shapeHSM_HsmPsfMoments_xx", doc="HSM moments", units="pixel^2"), Key<D>(offset=416, nElements=1)),
#     (Field['D'](name="ext_shapeHSM_HsmPsfMoments_yy", doc="HSM moments", units="pixel^2"), Key<D>(offset=424, nElements=1)),
#     (Field['D'](name="ext_shapeHSM_HsmPsfMoments_xy", doc="HSM moments", units="pixel^2"), Key<D>(offset=432, nElements=1)),
#     (Field['Flag'](name="ext_shapeHSM_HsmPsfMoments_flag", doc="general failure flag, set if anything went wrong"), Key['Flag'](offset=32, bit=44)),
#     (Field['Flag'](name="ext_shapeHSM_HsmPsfMoments_flag_no_pixels", doc="no pixels to measure"), Key['Flag'](offset=32, bit=45)),
#     (Field['Flag'](name="ext_shapeHSM_HsmPsfMoments_flag_not_contained", doc="center not contained in footprint bounding box"), Key['Flag'](offset=32, bit=46)),
#     (Field['Flag'](name="ext_shapeHSM_HsmPsfMoments_flag_parent_source", doc="parent source, ignored"), Key['Flag'](offset=32, bit=47)),
#     (Field['D'](name="ext_shapeHSM_HsmShapeBj_e1", doc="PSF-corrected shear using Bernstein & Jarvis (2002) method (+ component of ellipticity)"), Key<D>(offset=440, nElements=1)),
#     (Field['D'](name="ext_shapeHSM_HsmShapeBj_e2", doc="PSF-corrected shear using Bernstein & Jarvis (2002) method (x component of ellipticity)"), Key<D>(offset=448, nElements=1)),
#     (Field['D'](name="ext_shapeHSM_HsmShapeBj_sigma", doc="PSF-corrected shear using Bernstein & Jarvis (2002) method (width)"), Key<D>(offset=456, nElements=1)),
#     (Field['D'](name="ext_shapeHSM_HsmShapeBj_resolution", doc="resolution factor (0=unresolved, 1=resolved)"), Key<D>(offset=464, nElements=1)),
#     (Field['Flag'](name="ext_shapeHSM_HsmShapeBj_flag", doc="general failure flag, set if anything went wrong"), Key['Flag'](offset=32, bit=48)),
#     (Field['Flag'](name="ext_shapeHSM_HsmShapeBj_flag_no_pixels", doc="no pixels to measure"), Key['Flag'](offset=32, bit=49)),
#     (Field['Flag'](name="ext_shapeHSM_HsmShapeBj_flag_not_contained", doc="center not contained in footprint bounding box"), Key['Flag'](offset=32, bit=50)),
#     (Field['Flag'](name="ext_shapeHSM_HsmShapeBj_flag_parent_source", doc="parent source, ignored"), Key['Flag'](offset=32, bit=51)),
#     (Field['Flag'](name="ext_shapeHSM_HsmShapeBj_flag_galsim", doc="GalSim failure"), Key['Flag'](offset=32, bit=52)),
#     (Field['D'](name="ext_shapeHSM_HsmShapeKsb_g1", doc="PSF-corrected shear using KSB method (+ component of estimated shear)"), Key<D>(offset=472, nElements=1)),
#     (Field['D'](name="ext_shapeHSM_HsmShapeKsb_g2", doc="PSF-corrected shear using KSB method (x component of estimated shear)"), Key<D>(offset=480, nElements=1)),
#     (Field['D'](name="ext_shapeHSM_HsmShapeKsb_sigma", doc="PSF-corrected shear using KSB method (width)"), Key<D>(offset=488, nElements=1)),
#     (Field['D'](name="ext_shapeHSM_HsmShapeKsb_resolution", doc="resolution factor (0=unresolved, 1=resolved)"), Key<D>(offset=496, nElements=1)),
#     (Field['Flag'](name="ext_shapeHSM_HsmShapeKsb_flag", doc="general failure flag, set if anything went wrong"), Key['Flag'](offset=32, bit=53)),
#     (Field['Flag'](name="ext_shapeHSM_HsmShapeKsb_flag_no_pixels", doc="no pixels to measure"), Key['Flag'](offset=32, bit=54)),
#     (Field['Flag'](name="ext_shapeHSM_HsmShapeKsb_flag_not_contained", doc="center not contained in footprint bounding box"), Key['Flag'](offset=32, bit=55)),
#     (Field['Flag'](name="ext_shapeHSM_HsmShapeKsb_flag_parent_source", doc="parent source, ignored"), Key['Flag'](offset=32, bit=56)),
#     (Field['Flag'](name="ext_shapeHSM_HsmShapeKsb_flag_galsim", doc="GalSim failure"), Key['Flag'](offset=32, bit=57)),
#     (Field['D'](name="ext_shapeHSM_HsmShapeLinear_e1", doc="PSF-corrected shear using Hirata & Seljak (2003) ''linear'' method (+ component of ellipticity)"), Key<D>(offset=504, nElements=1)),
#     (Field['D'](name="ext_shapeHSM_HsmShapeLinear_e2", doc="PSF-corrected shear using Hirata & Seljak (2003) ''linear'' method (x component of ellipticity)"), Key<D>(offset=512, nElements=1)),
#     (Field['D'](name="ext_shapeHSM_HsmShapeLinear_sigma", doc="PSF-corrected shear using Hirata & Seljak (2003) ''linear'' method (width)"), Key<D>(offset=520, nElements=1)),
#     (Field['D'](name="ext_shapeHSM_HsmShapeLinear_resolution", doc="resolution factor (0=unresolved, 1=resolved)"), Key<D>(offset=528, nElements=1)),
#     (Field['Flag'](name="ext_shapeHSM_HsmShapeLinear_flag", doc="general failure flag, set if anything went wrong"), Key['Flag'](offset=32, bit=58)),
#     (Field['Flag'](name="ext_shapeHSM_HsmShapeLinear_flag_no_pixels", doc="no pixels to measure"), Key['Flag'](offset=32, bit=59)),
#     (Field['Flag'](name="ext_shapeHSM_HsmShapeLinear_flag_not_contained", doc="center not contained in footprint bounding box"), Key['Flag'](offset=32, bit=60)),
#     (Field['Flag'](name="ext_shapeHSM_HsmShapeLinear_flag_parent_source", doc="parent source, ignored"), Key['Flag'](offset=32, bit=61)),
#     (Field['Flag'](name="ext_shapeHSM_HsmShapeLinear_flag_galsim", doc="GalSim failure"), Key['Flag'](offset=32, bit=62)),
#     (Field['D'](name="ext_shapeHSM_HsmShapeRegauss_e1", doc="PSF-corrected shear using Hirata & Seljak (2003) ''regaussianization"), Key<D>(offset=536, nElements=1)),
#     (Field['D'](name="ext_shapeHSM_HsmShapeRegauss_e2", doc="PSF-corrected shear using Hirata & Seljak (2003) ''regaussianization"), Key<D>(offset=544, nElements=1)),
#     (Field['D'](name="ext_shapeHSM_HsmShapeRegauss_sigma", doc="PSF-corrected shear using Hirata & Seljak (2003) ''regaussianization"), Key<D>(offset=552, nElements=1)),
#     (Field['D'](name="ext_shapeHSM_HsmShapeRegauss_resolution", doc="resolution factor (0=unresolved, 1=resolved)"), Key<D>(offset=560, nElements=1)),
#     (Field['Flag'](name="ext_shapeHSM_HsmShapeRegauss_flag", doc="general failure flag, set if anything went wrong"), Key['Flag'](offset=32, bit=63)),
#     (Field['Flag'](name="ext_shapeHSM_HsmShapeRegauss_flag_no_pixels", doc="no pixels to measure"), Key['Flag'](offset=568, bit=0)),
#     (Field['Flag'](name="ext_shapeHSM_HsmShapeRegauss_flag_not_contained", doc="center not contained in footprint bounding box"), Key['Flag'](offset=568, bit=1)),
#     (Field['Flag'](name="ext_shapeHSM_HsmShapeRegauss_flag_parent_source", doc="parent source, ignored"), Key['Flag'](offset=568, bit=2)),
#     (Field['Flag'](name="ext_shapeHSM_HsmShapeRegauss_flag_galsim", doc="GalSim failure"), Key['Flag'](offset=568, bit=3)),
#     (Field['D'](name="ext_shapeHSM_HsmSourceMoments_x", doc="HSM Centroid", units="pixel"), Key<D>(offset=576, nElements=1)),
#     (Field['D'](name="ext_shapeHSM_HsmSourceMoments_y", doc="HSM Centroid", units="pixel"), Key<D>(offset=584, nElements=1)),
#     (Field['D'](name="ext_shapeHSM_HsmSourceMoments_xx", doc="HSM moments", units="pixel^2"), Key<D>(offset=592, nElements=1)),
#     (Field['D'](name="ext_shapeHSM_HsmSourceMoments_yy", doc="HSM moments", units="pixel^2"), Key<D>(offset=600, nElements=1)),
#     (Field['D'](name="ext_shapeHSM_HsmSourceMoments_xy", doc="HSM moments", units="pixel^2"), Key<D>(offset=608, nElements=1)),
#     (Field['Flag'](name="ext_shapeHSM_HsmSourceMoments_flag", doc="general failure flag, set if anything went wrong"), Key['Flag'](offset=568, bit=4)),
#     (Field['Flag'](name="ext_shapeHSM_HsmSourceMoments_flag_no_pixels", doc="no pixels to measure"), Key['Flag'](offset=568, bit=5)),
#     (Field['Flag'](name="ext_shapeHSM_HsmSourceMoments_flag_not_contained", doc="center not contained in footprint bounding box"), Key['Flag'](offset=568, bit=6)),
#     (Field['Flag'](name="ext_shapeHSM_HsmSourceMoments_flag_parent_source", doc="parent source, ignored"), Key['Flag'](offset=568, bit=7)),
#     (Field['D'](name="modelfit_DoubleShapeletPsfApprox_0_xx", doc="Double-Shapelet approximation to the PSF model at the position of this source", units="pixel^2"), Key<D>(offset=616, nElements=1)),
#     (Field['D'](name="modelfit_DoubleShapeletPsfApprox_0_yy", doc="Double-Shapelet approximation to the PSF model at the position of this source", units="pixel^2"), Key<D>(offset=624, nElements=1)),
#     (Field['D'](name="modelfit_DoubleShapeletPsfApprox_0_xy", doc="Double-Shapelet approximation to the PSF model at the position of this source", units="pixel^2"), Key<D>(offset=632, nElements=1)),
#     (Field['D'](name="modelfit_DoubleShapeletPsfApprox_0_x", doc="Double-Shapelet approximation to the PSF model at the position of this source", units="pixel"), Key<D>(offset=640, nElements=1)),
#     (Field['D'](name="modelfit_DoubleShapeletPsfApprox_0_y", doc="Double-Shapelet approximation to the PSF model at the position of this source", units="pixel"), Key<D>(offset=648, nElements=1)),
#     (Field['D'](name="modelfit_DoubleShapeletPsfApprox_0_0", doc="Double-Shapelet approximation to the PSF model at the position of this source"), Key<D>(offset=656, nElements=1)),
#     (Field['D'](name="modelfit_DoubleShapeletPsfApprox_0_1", doc="Double-Shapelet approximation to the PSF model at the position of this source"), Key<D>(offset=664, nElements=1)),
#     (Field['D'](name="modelfit_DoubleShapeletPsfApprox_0_2", doc="Double-Shapelet approximation to the PSF model at the position of this source"), Key<D>(offset=672, nElements=1)),
#     (Field['D'](name="modelfit_DoubleShapeletPsfApprox_0_3", doc="Double-Shapelet approximation to the PSF model at the position of this source"), Key<D>(offset=680, nElements=1)),
#     (Field['D'](name="modelfit_DoubleShapeletPsfApprox_0_4", doc="Double-Shapelet approximation to the PSF model at the position of this source"), Key<D>(offset=688, nElements=1)),
#     (Field['D'](name="modelfit_DoubleShapeletPsfApprox_0_5", doc="Double-Shapelet approximation to the PSF model at the position of this source"), Key<D>(offset=696, nElements=1)),
#     (Field['D'](name="modelfit_DoubleShapeletPsfApprox_1_xx", doc="Double-Shapelet approximation to the PSF model at the position of this source", units="pixel^2"), Key<D>(offset=704, nElements=1)),
#     (Field['D'](name="modelfit_DoubleShapeletPsfApprox_1_yy", doc="Double-Shapelet approximation to the PSF model at the position of this source", units="pixel^2"), Key<D>(offset=712, nElements=1)),
#     (Field['D'](name="modelfit_DoubleShapeletPsfApprox_1_xy", doc="Double-Shapelet approximation to the PSF model at the position of this source", units="pixel^2"), Key<D>(offset=720, nElements=1)),
#     (Field['D'](name="modelfit_DoubleShapeletPsfApprox_1_x", doc="Double-Shapelet approximation to the PSF model at the position of this source", units="pixel"), Key<D>(offset=728, nElements=1)),
#     (Field['D'](name="modelfit_DoubleShapeletPsfApprox_1_y", doc="Double-Shapelet approximation to the PSF model at the position of this source", units="pixel"), Key<D>(offset=736, nElements=1)),
#     (Field['D'](name="modelfit_DoubleShapeletPsfApprox_1_0", doc="Double-Shapelet approximation to the PSF model at the position of this source"), Key<D>(offset=744, nElements=1)),
#     (Field['D'](name="modelfit_DoubleShapeletPsfApprox_1_1", doc="Double-Shapelet approximation to the PSF model at the position of this source"), Key<D>(offset=752, nElements=1)),
#     (Field['D'](name="modelfit_DoubleShapeletPsfApprox_1_2", doc="Double-Shapelet approximation to the PSF model at the position of this source"), Key<D>(offset=760, nElements=1)),
#     (Field['Flag'](name="modelfit_DoubleShapeletPsfApprox_flag", doc="General Failure Flag"), Key['Flag'](offset=568, bit=8)),
#     (Field['Flag'](name="modelfit_DoubleShapeletPsfApprox_flag_invalidPointForPsf", doc="PSF model could not be evaluated at the source position"), Key['Flag'](offset=568, bit=9)),
#     (Field['Flag'](name="modelfit_DoubleShapeletPsfApprox_flag_invalidMoments", doc="Moments of the PSF model were not a valid ellipse"), Key['Flag'](offset=568, bit=10)),
#     (Field['Flag'](name="modelfit_DoubleShapeletPsfApprox_flag_maxIterations", doc="optimizer exceeded the maximum number (inner or outer) iterations"), Key['Flag'](offset=568, bit=11)),
#     (Field['D'](name="base_CircularApertureFlux_3_0_flux", doc="flux within 3.000000-pixel aperture", units="count"), Key<D>(offset=768, nElements=1)),
#     (Field['D'](name="base_CircularApertureFlux_3_0_fluxSigma", doc="1-sigma flux uncertainty", units="count"), Key<D>(offset=776, nElements=1)),
#     (Field['Flag'](name="base_CircularApertureFlux_3_0_flag", doc="General Failure Flag"), Key['Flag'](offset=568, bit=12)),
#     (Field['Flag'](name="base_CircularApertureFlux_3_0_flag_apertureTruncated", doc="aperture did not fit within measurement image"), Key['Flag'](offset=568, bit=13)),
#     (Field['Flag'](name="base_CircularApertureFlux_3_0_flag_sincCoeffsTruncated", doc="full sinc coefficient image did not fit within measurement image"), Key['Flag'](offset=568, bit=14)),
#     (Field['D'](name="base_CircularApertureFlux_4_5_flux", doc="flux within 4.500000-pixel aperture", units="count"), Key<D>(offset=784, nElements=1)),
#     (Field['D'](name="base_CircularApertureFlux_4_5_fluxSigma", doc="1-sigma flux uncertainty", units="count"), Key<D>(offset=792, nElements=1)),
#     (Field['Flag'](name="base_CircularApertureFlux_4_5_flag", doc="General Failure Flag"), Key['Flag'](offset=568, bit=15)),
#     (Field['Flag'](name="base_CircularApertureFlux_4_5_flag_apertureTruncated", doc="aperture did not fit within measurement image"), Key['Flag'](offset=568, bit=16)),
#     (Field['Flag'](name="base_CircularApertureFlux_4_5_flag_sincCoeffsTruncated", doc="full sinc coefficient image did not fit within measurement image"), Key['Flag'](offset=568, bit=17)),
#     (Field['D'](name="base_CircularApertureFlux_6_0_flux", doc="flux within 6.000000-pixel aperture", units="count"), Key<D>(offset=800, nElements=1)),
#     (Field['D'](name="base_CircularApertureFlux_6_0_fluxSigma", doc="1-sigma flux uncertainty", units="count"), Key<D>(offset=808, nElements=1)),
#     (Field['Flag'](name="base_CircularApertureFlux_6_0_flag", doc="General Failure Flag"), Key['Flag'](offset=568, bit=18)),
#     (Field['Flag'](name="base_CircularApertureFlux_6_0_flag_apertureTruncated", doc="aperture did not fit within measurement image"), Key['Flag'](offset=568, bit=19)),
#     (Field['Flag'](name="base_CircularApertureFlux_6_0_flag_sincCoeffsTruncated", doc="full sinc coefficient image did not fit within measurement image"), Key['Flag'](offset=568, bit=20)),
#     (Field['D'](name="base_CircularApertureFlux_9_0_flux", doc="flux within 9.000000-pixel aperture", units="count"), Key<D>(offset=816, nElements=1)),
#     (Field['D'](name="base_CircularApertureFlux_9_0_fluxSigma", doc="1-sigma flux uncertainty", units="count"), Key<D>(offset=824, nElements=1)),
#     (Field['Flag'](name="base_CircularApertureFlux_9_0_flag", doc="General Failure Flag"), Key['Flag'](offset=568, bit=21)),
#     (Field['Flag'](name="base_CircularApertureFlux_9_0_flag_apertureTruncated", doc="aperture did not fit within measurement image"), Key['Flag'](offset=568, bit=22)),
#     (Field['Flag'](name="base_CircularApertureFlux_9_0_flag_sincCoeffsTruncated", doc="full sinc coefficient image did not fit within measurement image"), Key['Flag'](offset=568, bit=23)),
#     (Field['D'](name="base_CircularApertureFlux_12_0_flux", doc="flux within 12.000000-pixel aperture", units="count"), Key<D>(offset=832, nElements=1)),
#     (Field['D'](name="base_CircularApertureFlux_12_0_fluxSigma", doc="1-sigma flux uncertainty", units="count"), Key<D>(offset=840, nElements=1)),
#     (Field['Flag'](name="base_CircularApertureFlux_12_0_flag", doc="General Failure Flag"), Key['Flag'](offset=568, bit=24)),
#     (Field['Flag'](name="base_CircularApertureFlux_12_0_flag_apertureTruncated", doc="aperture did not fit within measurement image"), Key['Flag'](offset=568, bit=25)),
#     (Field['D'](name="base_CircularApertureFlux_17_0_flux", doc="flux within 17.000000-pixel aperture", units="count"), Key<D>(offset=848, nElements=1)),
#     (Field['D'](name="base_CircularApertureFlux_17_0_fluxSigma", doc="1-sigma flux uncertainty", units="count"), Key<D>(offset=856, nElements=1)),
#     (Field['Flag'](name="base_CircularApertureFlux_17_0_flag", doc="General Failure Flag"), Key['Flag'](offset=568, bit=26)),
#     (Field['Flag'](name="base_CircularApertureFlux_17_0_flag_apertureTruncated", doc="aperture did not fit within measurement image"), Key['Flag'](offset=568, bit=27)),
#     (Field['D'](name="base_CircularApertureFlux_25_0_flux", doc="flux within 25.000000-pixel aperture", units="count"), Key<D>(offset=864, nElements=1)),
#     (Field['D'](name="base_CircularApertureFlux_25_0_fluxSigma", doc="1-sigma flux uncertainty", units="count"), Key<D>(offset=872, nElements=1)),
#     (Field['Flag'](name="base_CircularApertureFlux_25_0_flag", doc="General Failure Flag"), Key['Flag'](offset=568, bit=28)),
#     (Field['Flag'](name="base_CircularApertureFlux_25_0_flag_apertureTruncated", doc="aperture did not fit within measurement image"), Key['Flag'](offset=568, bit=29)),
#     (Field['D'](name="base_CircularApertureFlux_35_0_flux", doc="flux within 35.000000-pixel aperture", units="count"), Key<D>(offset=880, nElements=1)),
#     (Field['D'](name="base_CircularApertureFlux_35_0_fluxSigma", doc="1-sigma flux uncertainty", units="count"), Key<D>(offset=888, nElements=1)),
#     (Field['Flag'](name="base_CircularApertureFlux_35_0_flag", doc="General Failure Flag"), Key['Flag'](offset=568, bit=30)),
#     (Field['Flag'](name="base_CircularApertureFlux_35_0_flag_apertureTruncated", doc="aperture did not fit within measurement image"), Key['Flag'](offset=568, bit=31)),
#     (Field['D'](name="base_CircularApertureFlux_50_0_flux", doc="flux within 50.000000-pixel aperture", units="count"), Key<D>(offset=896, nElements=1)),
#     (Field['D'](name="base_CircularApertureFlux_50_0_fluxSigma", doc="1-sigma flux uncertainty", units="count"), Key<D>(offset=904, nElements=1)),
#     (Field['Flag'](name="base_CircularApertureFlux_50_0_flag", doc="General Failure Flag"), Key['Flag'](offset=568, bit=32)),
#     (Field['Flag'](name="base_CircularApertureFlux_50_0_flag_apertureTruncated", doc="aperture did not fit within measurement image"), Key['Flag'](offset=568, bit=33)),
#     (Field['D'](name="base_CircularApertureFlux_70_0_flux", doc="flux within 70.000000-pixel aperture", units="count"), Key<D>(offset=912, nElements=1)),
#     (Field['D'](name="base_CircularApertureFlux_70_0_fluxSigma", doc="1-sigma flux uncertainty", units="count"), Key<D>(offset=920, nElements=1)),
#     (Field['Flag'](name="base_CircularApertureFlux_70_0_flag", doc="General Failure Flag"), Key['Flag'](offset=568, bit=34)),
#     (Field['Flag'](name="base_CircularApertureFlux_70_0_flag_apertureTruncated", doc="aperture did not fit within measurement image"), Key['Flag'](offset=568, bit=35)),
#     (Field['D'](name="base_GaussianFlux_flux", doc="flux from Gaussian Flux algorithm", units="count"), Key<D>(offset=928, nElements=1)),
#     (Field['D'](name="base_GaussianFlux_fluxSigma", doc="1-sigma flux uncertainty", units="count"), Key<D>(offset=936, nElements=1)),
#     (Field['Flag'](name="base_GaussianFlux_flag", doc="General Failure Flag"), Key['Flag'](offset=568, bit=36)),
#     (Field['Flag'](name="base_PixelFlags_flag", doc="general failure flag, set if anything went wring"), Key['Flag'](offset=568, bit=37)),
#     (Field['Flag'](name="base_PixelFlags_flag_offimage", doc="Source center is off image"), Key['Flag'](offset=568, bit=38)),
#     (Field['Flag'](name="base_PixelFlags_flag_edge", doc="Source is outside usable exposure region (masked EDGE or NO_DATA)"), Key['Flag'](offset=568, bit=39)),
#     (Field['Flag'](name="base_PixelFlags_flag_interpolated", doc="Interpolated pixel in the Source footprint"), Key['Flag'](offset=568, bit=40)),
#     (Field['Flag'](name="base_PixelFlags_flag_saturated", doc="Saturated pixel in the Source footprint"), Key['Flag'](offset=568, bit=41)),
#     (Field['Flag'](name="base_PixelFlags_flag_cr", doc="Cosmic ray in the Source footprint"), Key['Flag'](offset=568, bit=42)),
#     (Field['Flag'](name="base_PixelFlags_flag_bad", doc="Bad pixel in the Source footprint"), Key['Flag'](offset=568, bit=43)),
#     (Field['Flag'](name="base_PixelFlags_flag_suspect", doc="Source''s footprint includes suspect pixels"), Key['Flag'](offset=568, bit=44)),
#     (Field['Flag'](name="base_PixelFlags_flag_interpolatedCenter", doc="Interpolated pixel in the Source center"), Key['Flag'](offset=568, bit=45)),
#     (Field['Flag'](name="base_PixelFlags_flag_saturatedCenter", doc="Saturated pixel in the Source center"), Key['Flag'](offset=568, bit=46)),
#     (Field['Flag'](name="base_PixelFlags_flag_crCenter", doc="Cosmic ray in the Source center"), Key['Flag'](offset=568, bit=47)),
#     (Field['Flag'](name="base_PixelFlags_flag_suspectCenter", doc="Source''s center is close to suspect pixels"), Key['Flag'](offset=568, bit=48)),
#     (Field['Flag'](name="base_PixelFlags_flag_clipped", doc="Source footprint includes CLIPPED pixels"), Key['Flag'](offset=568, bit=49)),
#     (Field['Flag'](name="base_PixelFlags_flag_sensor_edge", doc="Source footprint includes SENSOR_EDGE pixels"), Key['Flag'](offset=568, bit=50)),
#     (Field['Flag'](name="base_PixelFlags_flag_inexact_psf", doc="Source footprint includes INEXACT_PSF pixels"), Key['Flag'](offset=568, bit=51)),
#     (Field['D'](name="base_PsfFlux_flux", doc="flux derived from linear least-squares fit of PSF model", units="count"), Key<D>(offset=944, nElements=1)),
#     (Field['D'](name="base_PsfFlux_fluxSigma", doc="1-sigma flux uncertainty", units="count"), Key<D>(offset=952, nElements=1)),
#     (Field['Flag'](name="base_PsfFlux_flag", doc="General Failure Flag"), Key['Flag'](offset=568, bit=52)),
#     (Field['Flag'](name="base_PsfFlux_flag_noGoodPixels", doc="not enough non-rejected pixels in data to attempt the fit"), Key['Flag'](offset=568, bit=53)),
#     (Field['Flag'](name="base_PsfFlux_flag_edge", doc="object was too close to the edge of the image to use the full PSF model"), Key['Flag'](offset=568, bit=54)),
#     (Field['Flag'](name="base_Variance_flag", doc="Set for any fatal failure"), Key['Flag'](offset=568, bit=55)),
#     (Field['D'](name="base_Variance_value", doc="Variance at object position"), Key<D>(offset=960, nElements=1)),
#     (Field['Flag'](name="base_Variance_flag_emptyFootprint", doc="Set to True when the footprint has no usable pixels"), Key['Flag'](offset=568, bit=56)),
#     (Field['F'](name="ext_convolved_ConvolvedFlux_seeing", doc="original seeing (Gaussian sigma) at position", units="pixel"), Key<F>(offset=968, nElements=1)),
#     (Field['Flag'](name="ext_convolved_ConvolvedFlux_0_deconv", doc="deconvolution required for seeing 3.500000; no measurement made"), Key['Flag'](offset=568, bit=57)),
#     (Field['D'](name="ext_convolved_ConvolvedFlux_0_3_3_flux", doc="flux within 3.300000-pixel aperture", units="count"), Key<D>(offset=976, nElements=1)),
#     (Field['D'](name="ext_convolved_ConvolvedFlux_0_3_3_fluxSigma", doc="1-sigma flux uncertainty", units="count"), Key<D>(offset=984, nElements=1)),
#     (Field['Flag'](name="ext_convolved_ConvolvedFlux_0_3_3_flag", doc="General Failure Flag"), Key['Flag'](offset=568, bit=58)),
#     (Field['Flag'](name="ext_convolved_ConvolvedFlux_0_3_3_flag_apertureTruncated", doc="aperture did not fit within measurement image"), Key['Flag'](offset=568, bit=59)),
#     (Field['Flag'](name="ext_convolved_ConvolvedFlux_0_3_3_flag_sincCoeffsTruncated", doc="full sinc coefficient image did not fit within measurement image"), Key['Flag'](offset=568, bit=60)),
#     (Field['D'](name="ext_convolved_ConvolvedFlux_0_4_5_flux", doc="flux within 4.500000-pixel aperture", units="count"), Key<D>(offset=992, nElements=1)),
#     (Field['D'](name="ext_convolved_ConvolvedFlux_0_4_5_fluxSigma", doc="1-sigma flux uncertainty", units="count"), Key<D>(offset=1000, nElements=1)),
#     (Field['Flag'](name="ext_convolved_ConvolvedFlux_0_4_5_flag", doc="General Failure Flag"), Key['Flag'](offset=568, bit=61)),
#     (Field['Flag'](name="ext_convolved_ConvolvedFlux_0_4_5_flag_apertureTruncated", doc="aperture did not fit within measurement image"), Key['Flag'](offset=568, bit=62)),
#     (Field['Flag'](name="ext_convolved_ConvolvedFlux_0_4_5_flag_sincCoeffsTruncated", doc="full sinc coefficient image did not fit within measurement image"), Key['Flag'](offset=568, bit=63)),
#     (Field['D'](name="ext_convolved_ConvolvedFlux_0_6_0_flux", doc="flux within 6.000000-pixel aperture", units="count"), Key<D>(offset=1008, nElements=1)),
#     (Field['D'](name="ext_convolved_ConvolvedFlux_0_6_0_fluxSigma", doc="1-sigma flux uncertainty", units="count"), Key<D>(offset=1016, nElements=1)),
#     (Field['Flag'](name="ext_convolved_ConvolvedFlux_0_6_0_flag", doc="General Failure Flag"), Key['Flag'](offset=1024, bit=0)),
#     (Field['Flag'](name="ext_convolved_ConvolvedFlux_0_6_0_flag_apertureTruncated", doc="aperture did not fit within measurement image"), Key['Flag'](offset=1024, bit=1)),
#     (Field['Flag'](name="ext_convolved_ConvolvedFlux_0_6_0_flag_sincCoeffsTruncated", doc="full sinc coefficient image did not fit within measurement image"), Key['Flag'](offset=1024, bit=2)),
#     (Field['D'](name="ext_convolved_ConvolvedFlux_0_kron_flux", doc="convolved Kron flux: seeing 3.500000", units="count"), Key<D>(offset=1032, nElements=1)),
#     (Field['D'](name="ext_convolved_ConvolvedFlux_0_kron_fluxSigma", doc="1-sigma flux uncertainty", units="count"), Key<D>(offset=1040, nElements=1)),
#     (Field['Flag'](name="ext_convolved_ConvolvedFlux_0_kron_flag", doc="convolved Kron flux failed: seeing 3.500000"), Key['Flag'](offset=1024, bit=3)),
#     (Field['Flag'](name="ext_convolved_ConvolvedFlux_1_deconv", doc="deconvolution required for seeing 5.000000; no measurement made"), Key['Flag'](offset=1024, bit=4)),
#     (Field['D'](name="ext_convolved_ConvolvedFlux_1_3_3_flux", doc="flux within 3.300000-pixel aperture", units="count"), Key<D>(offset=1048, nElements=1)),
#     (Field['D'](name="ext_convolved_ConvolvedFlux_1_3_3_fluxSigma", doc="1-sigma flux uncertainty", units="count"), Key<D>(offset=1056, nElements=1)),
#     (Field['Flag'](name="ext_convolved_ConvolvedFlux_1_3_3_flag", doc="General Failure Flag"), Key['Flag'](offset=1024, bit=5)),
#     (Field['Flag'](name="ext_convolved_ConvolvedFlux_1_3_3_flag_apertureTruncated", doc="aperture did not fit within measurement image"), Key['Flag'](offset=1024, bit=6)),
#     (Field['Flag'](name="ext_convolved_ConvolvedFlux_1_3_3_flag_sincCoeffsTruncated", doc="full sinc coefficient image did not fit within measurement image"), Key['Flag'](offset=1024, bit=7)),
#     (Field['D'](name="ext_convolved_ConvolvedFlux_1_4_5_flux", doc="flux within 4.500000-pixel aperture", units="count"), Key<D>(offset=1064, nElements=1)),
#     (Field['D'](name="ext_convolved_ConvolvedFlux_1_4_5_fluxSigma", doc="1-sigma flux uncertainty", units="count"), Key<D>(offset=1072, nElements=1)),
#     (Field['Flag'](name="ext_convolved_ConvolvedFlux_1_4_5_flag", doc="General Failure Flag"), Key['Flag'](offset=1024, bit=8)),
#     (Field['Flag'](name="ext_convolved_ConvolvedFlux_1_4_5_flag_apertureTruncated", doc="aperture did not fit within measurement image"), Key['Flag'](offset=1024, bit=9)),
#     (Field['Flag'](name="ext_convolved_ConvolvedFlux_1_4_5_flag_sincCoeffsTruncated", doc="full sinc coefficient image did not fit within measurement image"), Key['Flag'](offset=1024, bit=10)),
#     (Field['D'](name="ext_convolved_ConvolvedFlux_1_6_0_flux", doc="flux within 6.000000-pixel aperture", units="count"), Key<D>(offset=1080, nElements=1)),
#     (Field['D'](name="ext_convolved_ConvolvedFlux_1_6_0_fluxSigma", doc="1-sigma flux uncertainty", units="count"), Key<D>(offset=1088, nElements=1)),
#     (Field['Flag'](name="ext_convolved_ConvolvedFlux_1_6_0_flag", doc="General Failure Flag"), Key['Flag'](offset=1024, bit=11)),
#     (Field['Flag'](name="ext_convolved_ConvolvedFlux_1_6_0_flag_apertureTruncated", doc="aperture did not fit within measurement image"), Key['Flag'](offset=1024, bit=12)),
#     (Field['Flag'](name="ext_convolved_ConvolvedFlux_1_6_0_flag_sincCoeffsTruncated", doc="full sinc coefficient image did not fit within measurement image"), Key['Flag'](offset=1024, bit=13)),
#     (Field['D'](name="ext_convolved_ConvolvedFlux_1_kron_flux", doc="convolved Kron flux: seeing 5.000000", units="count"), Key<D>(offset=1096, nElements=1)),
#     (Field['D'](name="ext_convolved_ConvolvedFlux_1_kron_fluxSigma", doc="1-sigma flux uncertainty", units="count"), Key<D>(offset=1104, nElements=1)),
#     (Field['Flag'](name="ext_convolved_ConvolvedFlux_1_kron_flag", doc="convolved Kron flux failed: seeing 5.000000"), Key['Flag'](offset=1024, bit=14)),
#     (Field['Flag'](name="ext_convolved_ConvolvedFlux_2_deconv", doc="deconvolution required for seeing 6.500000; no measurement made"), Key['Flag'](offset=1024, bit=15)),
#     (Field['D'](name="ext_convolved_ConvolvedFlux_2_3_3_flux", doc="flux within 3.300000-pixel aperture", units="count"), Key<D>(offset=1112, nElements=1)),
#     (Field['D'](name="ext_convolved_ConvolvedFlux_2_3_3_fluxSigma", doc="1-sigma flux uncertainty", units="count"), Key<D>(offset=1120, nElements=1)),
#     (Field['Flag'](name="ext_convolved_ConvolvedFlux_2_3_3_flag", doc="General Failure Flag"), Key['Flag'](offset=1024, bit=16)),
#     (Field['Flag'](name="ext_convolved_ConvolvedFlux_2_3_3_flag_apertureTruncated", doc="aperture did not fit within measurement image"), Key['Flag'](offset=1024, bit=17)),
#     (Field['Flag'](name="ext_convolved_ConvolvedFlux_2_3_3_flag_sincCoeffsTruncated", doc="full sinc coefficient image did not fit within measurement image"), Key['Flag'](offset=1024, bit=18)),
#     (Field['D'](name="ext_convolved_ConvolvedFlux_2_4_5_flux", doc="flux within 4.500000-pixel aperture", units="count"), Key<D>(offset=1128, nElements=1)),
#     (Field['D'](name="ext_convolved_ConvolvedFlux_2_4_5_fluxSigma", doc="1-sigma flux uncertainty", units="count"), Key<D>(offset=1136, nElements=1)),
#     (Field['Flag'](name="ext_convolved_ConvolvedFlux_2_4_5_flag", doc="General Failure Flag"), Key['Flag'](offset=1024, bit=19)),
#     (Field['Flag'](name="ext_convolved_ConvolvedFlux_2_4_5_flag_apertureTruncated", doc="aperture did not fit within measurement image"), Key['Flag'](offset=1024, bit=20)),
#     (Field['Flag'](name="ext_convolved_ConvolvedFlux_2_4_5_flag_sincCoeffsTruncated", doc="full sinc coefficient image did not fit within measurement image"), Key['Flag'](offset=1024, bit=21)),
#     (Field['D'](name="ext_convolved_ConvolvedFlux_2_6_0_flux", doc="flux within 6.000000-pixel aperture", units="count"), Key<D>(offset=1144, nElements=1)),
#     (Field['D'](name="ext_convolved_ConvolvedFlux_2_6_0_fluxSigma", doc="1-sigma flux uncertainty", units="count"), Key<D>(offset=1152, nElements=1)),
#     (Field['Flag'](name="ext_convolved_ConvolvedFlux_2_6_0_flag", doc="General Failure Flag"), Key['Flag'](offset=1024, bit=22)),
#     (Field['Flag'](name="ext_convolved_ConvolvedFlux_2_6_0_flag_apertureTruncated", doc="aperture did not fit within measurement image"), Key['Flag'](offset=1024, bit=23)),
#     (Field['Flag'](name="ext_convolved_ConvolvedFlux_2_6_0_flag_sincCoeffsTruncated", doc="full sinc coefficient image did not fit within measurement image"), Key['Flag'](offset=1024, bit=24)),
#     (Field['D'](name="ext_convolved_ConvolvedFlux_2_kron_flux", doc="convolved Kron flux: seeing 6.500000", units="count"), Key<D>(offset=1160, nElements=1)),
#     (Field['D'](name="ext_convolved_ConvolvedFlux_2_kron_fluxSigma", doc="1-sigma flux uncertainty", units="count"), Key<D>(offset=1168, nElements=1)),
#     (Field['Flag'](name="ext_convolved_ConvolvedFlux_2_kron_flag", doc="convolved Kron flux failed: seeing 6.500000"), Key['Flag'](offset=1024, bit=25)),
#     (Field['Flag'](name="ext_convolved_ConvolvedFlux_3_deconv", doc="deconvolution required for seeing 8.000000; no measurement made"), Key['Flag'](offset=1024, bit=26)),
#     (Field['D'](name="ext_convolved_ConvolvedFlux_3_3_3_flux", doc="flux within 3.300000-pixel aperture", units="count"), Key<D>(offset=1176, nElements=1)),
#     (Field['D'](name="ext_convolved_ConvolvedFlux_3_3_3_fluxSigma", doc="1-sigma flux uncertainty", units="count"), Key<D>(offset=1184, nElements=1)),
#     (Field['Flag'](name="ext_convolved_ConvolvedFlux_3_3_3_flag", doc="General Failure Flag"), Key['Flag'](offset=1024, bit=27)),
#     (Field['Flag'](name="ext_convolved_ConvolvedFlux_3_3_3_flag_apertureTruncated", doc="aperture did not fit within measurement image"), Key['Flag'](offset=1024, bit=28)),
#     (Field['Flag'](name="ext_convolved_ConvolvedFlux_3_3_3_flag_sincCoeffsTruncated", doc="full sinc coefficient image did not fit within measurement image"), Key['Flag'](offset=1024, bit=29)),
#     (Field['D'](name="ext_convolved_ConvolvedFlux_3_4_5_flux", doc="flux within 4.500000-pixel aperture", units="count"), Key<D>(offset=1192, nElements=1)),
#     (Field['D'](name="ext_convolved_ConvolvedFlux_3_4_5_fluxSigma", doc="1-sigma flux uncertainty", units="count"), Key<D>(offset=1200, nElements=1)),
#     (Field['Flag'](name="ext_convolved_ConvolvedFlux_3_4_5_flag", doc="General Failure Flag"), Key['Flag'](offset=1024, bit=30)),
#     (Field['Flag'](name="ext_convolved_ConvolvedFlux_3_4_5_flag_apertureTruncated", doc="aperture did not fit within measurement image"), Key['Flag'](offset=1024, bit=31)),
#     (Field['Flag'](name="ext_convolved_ConvolvedFlux_3_4_5_flag_sincCoeffsTruncated", doc="full sinc coefficient image did not fit within measurement image"), Key['Flag'](offset=1024, bit=32)),
#     (Field['D'](name="ext_convolved_ConvolvedFlux_3_6_0_flux", doc="flux within 6.000000-pixel aperture", units="count"), Key<D>(offset=1208, nElements=1)),
#     (Field['D'](name="ext_convolved_ConvolvedFlux_3_6_0_fluxSigma", doc="1-sigma flux uncertainty", units="count"), Key<D>(offset=1216, nElements=1)),
#     (Field['Flag'](name="ext_convolved_ConvolvedFlux_3_6_0_flag", doc="General Failure Flag"), Key['Flag'](offset=1024, bit=33)),
# ...
#     (Field['D'](name="modelfit_CModel_region_initial_ellipse_yy", doc="ellipse used to set the pixel region for the initial fit (before applying bad pixel mask)", units="pixel^2"), Key<D>(offset=1648, nElements=1)),
#     (Field['D'](name="modelfit_CModel_region_initial_ellipse_xy", doc="ellipse used to set the pixel region for the initial fit (before applying bad pixel mask)", units="pixel^2"), Key<D>(offset=1656, nElements=1)),
#     (Field['D'](name="modelfit_CModel_region_final_ellipse_xx", doc="ellipse used to set the pixel region for the final fit (before applying bad pixel mask)", units="pixel^2"), Key<D>(offset=1664, nElements=1)),
#     (Field['D'](name="modelfit_CModel_region_final_ellipse_yy", doc="ellipse used to set the pixel region for the final fit (before applying bad pixel mask)", units="pixel^2"), Key<D>(offset=1672, nElements=1)),
#     (Field['D'](name="modelfit_CModel_region_final_ellipse_xy", doc="ellipse used to set the pixel region for the final fit (before applying bad pixel mask)", units="pixel^2"), Key<D>(offset=1680, nElements=1)),
#     (Field['Flag'](name="modelfit_CModel_flag_noShapeletPsf", doc="the multishapelet fit to the PSF model did not succeed"), Key['Flag'](offset=1024, bit=59)),
#     (Field['Flag'](name="modelfit_CModel_flag_badCentroid", doc="input centroid was not within the fit region (probably because it''s not within the Footprint)"), Key['Flag'](offset=1024, bit=60)),
#     (Field['Flag'](name="detect_isPatchInner", doc="true if source is in the inner region of a coadd patch"), Key['Flag'](offset=1024, bit=61)),
#     (Field['Flag'](name="detect_isTractInner", doc="true if source is in the inner region of a coadd tract"), Key['Flag'](offset=1024, bit=62)),
#     (Field['Flag'](name="detect_isPrimary", doc="true if source has no children and is in the inner region of a coadd patch and is in the inner region of a coadd tract and is not "detected" in a pseudo-filter (see config.pseudoFilterList)"), Key['Flag'](offset=1024, bit=63)),
#     (Field['Flag'](name="calib_psfCandidate", doc="Propagated from visits"), Key['Flag'](offset=1688, bit=0)),
#     (Field['Flag'](name="calib_psfUsed", doc="Propagated from visits"), Key['Flag'](offset=1688, bit=1)),
#     (Field['D'](name="ext_convolved_ConvolvedFlux_0_kron_apCorr", doc="aperture correction applied to ext_convolved_ConvolvedFlux_0_kron"), Key<D>(offset=1696, nElements=1)),
#     (Field['D'](name="ext_convolved_ConvolvedFlux_0_kron_apCorrSigma", doc="aperture correction applied to ext_convolved_ConvolvedFlux_0_kron"), Key<D>(offset=1704, nElements=1)),
#     (Field['Flag'](name="ext_convolved_ConvolvedFlux_0_kron_flag_apCorr", doc="set if unable to aperture correct ext_convolved_ConvolvedFlux_0_kron"), Key['Flag'](offset=1688, bit=2)),
#     (Field['D'](name="ext_convolved_ConvolvedFlux_2_4_5_apCorr", doc="aperture correction applied to ext_convolved_ConvolvedFlux_2_4_5"), Key<D>(offset=1712, nElements=1)),
#     (Field['D'](name="ext_convolved_ConvolvedFlux_2_4_5_apCorrSigma", doc="aperture correction applied to ext_convolved_ConvolvedFlux_2_4_5"), Key<D>(offset=1720, nElements=1)),
#     (Field['Flag'](name="ext_convolved_ConvolvedFlux_2_4_5_flag_apCorr", doc="set if unable to aperture correct ext_convolved_ConvolvedFlux_2_4_5"), Key['Flag'](offset=1688, bit=3)),
#     (Field['D'](name="modelfit_CModel_apCorr", doc="aperture correction applied to modelfit_CModel"), Key<D>(offset=1728, nElements=1)),
#     (Field['D'](name="modelfit_CModel_apCorrSigma", doc="aperture correction applied to modelfit_CModel"), Key<D>(offset=1736, nElements=1)),
#     (Field['Flag'](name="modelfit_CModel_flag_apCorr", doc="set if unable to aperture correct modelfit_CModel"), Key['Flag'](offset=1688, bit=4)),
#     (Field['D'](name="ext_convolved_ConvolvedFlux_2_3_3_apCorr", doc="aperture correction applied to ext_convolved_ConvolvedFlux_2_3_3"), Key<D>(offset=1744, nElements=1)),
#     (Field['D'](name="ext_convolved_ConvolvedFlux_2_3_3_apCorrSigma", doc="aperture correction applied to ext_convolved_ConvolvedFlux_2_3_3"), Key<D>(offset=1752, nElements=1)),
#     (Field['Flag'](name="ext_convolved_ConvolvedFlux_2_3_3_flag_apCorr", doc="set if unable to aperture correct ext_convolved_ConvolvedFlux_2_3_3"), Key['Flag'](offset=1688, bit=5)),
#     (Field['D'](name="ext_convolved_ConvolvedFlux_1_6_0_apCorr", doc="aperture correction applied to ext_convolved_ConvolvedFlux_1_6_0"), Key<D>(offset=1760, nElements=1)),
#     (Field['D'](name="ext_convolved_ConvolvedFlux_1_6_0_apCorrSigma", doc="aperture correction applied to ext_convolved_ConvolvedFlux_1_6_0"), Key<D>(offset=1768, nElements=1)),
#     (Field['Flag'](name="ext_convolved_ConvolvedFlux_1_6_0_flag_apCorr", doc="set if unable to aperture correct ext_convolved_ConvolvedFlux_1_6_0"), Key['Flag'](offset=1688, bit=6)),
#     (Field['D'](name="modelfit_CModel_dev_apCorr", doc="aperture correction applied to modelfit_CModel_dev"), Key<D>(offset=1776, nElements=1)),
#     (Field['D'](name="modelfit_CModel_dev_apCorrSigma", doc="aperture correction applied to modelfit_CModel_dev"), Key<D>(offset=1784, nElements=1)),
#     (Field['Flag'](name="modelfit_CModel_dev_flag_apCorr", doc="set if unable to aperture correct modelfit_CModel_dev"), Key['Flag'](offset=1688, bit=7)),
#     (Field['D'](name="ext_convolved_ConvolvedFlux_0_3_3_apCorr", doc="aperture correction applied to ext_convolved_ConvolvedFlux_0_3_3"), Key<D>(offset=1792, nElements=1)),
#     (Field['D'](name="ext_convolved_ConvolvedFlux_0_3_3_apCorrSigma", doc="aperture correction applied to ext_convolved_ConvolvedFlux_0_3_3"), Key<D>(offset=1800, nElements=1)),
#     (Field['Flag'](name="ext_convolved_ConvolvedFlux_0_3_3_flag_apCorr", doc="set if unable to aperture correct ext_convolved_ConvolvedFlux_0_3_3"), Key['Flag'](offset=1688, bit=8)),
#     (Field['D'](name="ext_convolved_ConvolvedFlux_0_4_5_apCorr", doc="aperture correction applied to ext_convolved_ConvolvedFlux_0_4_5"), Key<D>(offset=1808, nElements=1)),
#     (Field['D'](name="ext_convolved_ConvolvedFlux_0_4_5_apCorrSigma", doc="aperture correction applied to ext_convolved_ConvolvedFlux_0_4_5"), Key<D>(offset=1816, nElements=1)),
#     (Field['Flag'](name="ext_convolved_ConvolvedFlux_0_4_5_flag_apCorr", doc="set if unable to aperture correct ext_convolved_ConvolvedFlux_0_4_5"), Key['Flag'](offset=1688, bit=9)),
#     (Field['D'](name="ext_convolved_ConvolvedFlux_3_3_3_apCorr", doc="aperture correction applied to ext_convolved_ConvolvedFlux_3_3_3"), Key<D>(offset=1824, nElements=1)),
#     (Field['D'](name="ext_convolved_ConvolvedFlux_3_3_3_apCorrSigma", doc="aperture correction applied to ext_convolved_ConvolvedFlux_3_3_3"), Key<D>(offset=1832, nElements=1)),
#     (Field['Flag'](name="ext_convolved_ConvolvedFlux_3_3_3_flag_apCorr", doc="set if unable to aperture correct ext_convolved_ConvolvedFlux_3_3_3"), Key['Flag'](offset=1688, bit=10)),
#     (Field['D'](name="base_PsfFlux_apCorr", doc="aperture correction applied to base_PsfFlux"), Key<D>(offset=1840, nElements=1)),
#     (Field['D'](name="base_PsfFlux_apCorrSigma", doc="aperture correction applied to base_PsfFlux"), Key<D>(offset=1848, nElements=1)),
#     (Field['Flag'](name="base_PsfFlux_flag_apCorr", doc="set if unable to aperture correct base_PsfFlux"), Key['Flag'](offset=1688, bit=11)),
#     (Field['D'](name="ext_convolved_ConvolvedFlux_3_kron_apCorr", doc="aperture correction applied to ext_convolved_ConvolvedFlux_3_kron"), Key<D>(offset=1856, nElements=1)),
#     (Field['D'](name="ext_convolved_ConvolvedFlux_3_kron_apCorrSigma", doc="aperture correction applied to ext_convolved_ConvolvedFlux_3_kron"), Key<D>(offset=1864, nElements=1)),
#     (Field['Flag'](name="ext_convolved_ConvolvedFlux_3_kron_flag_apCorr", doc="set if unable to aperture correct ext_convolved_ConvolvedFlux_3_kron"), Key['Flag'](offset=1688, bit=12)),
#     (Field['D'](name="ext_convolved_ConvolvedFlux_1_kron_apCorr", doc="aperture correction applied to ext_convolved_ConvolvedFlux_1_kron"), Key<D>(offset=1872, nElements=1)),
#     (Field['D'](name="ext_convolved_ConvolvedFlux_1_kron_apCorrSigma", doc="aperture correction applied to ext_convolved_ConvolvedFlux_1_kron"), Key<D>(offset=1880, nElements=1)),
#     (Field['Flag'](name="ext_convolved_ConvolvedFlux_1_kron_flag_apCorr", doc="set if unable to aperture correct ext_convolved_ConvolvedFlux_1_kron"), Key['Flag'](offset=1688, bit=13)),
#     (Field['D'](name="modelfit_CModel_initial_apCorr", doc="aperture correction applied to modelfit_CModel_initial"), Key<D>(offset=1888, nElements=1)),
#     (Field['D'](name="modelfit_CModel_initial_apCorrSigma", doc="aperture correction applied to modelfit_CModel_initial"), Key<D>(offset=1896, nElements=1)),
#     (Field['Flag'](name="modelfit_CModel_initial_flag_apCorr", doc="set if unable to aperture correct modelfit_CModel_initial"), Key['Flag'](offset=1688, bit=14)),
#     (Field['D'](name="ext_convolved_ConvolvedFlux_3_4_5_apCorr", doc="aperture correction applied to ext_convolved_ConvolvedFlux_3_4_5"), Key<D>(offset=1904, nElements=1)),
#     (Field['D'](name="ext_convolved_ConvolvedFlux_3_4_5_apCorrSigma", doc="aperture correction applied to ext_convolved_ConvolvedFlux_3_4_5"), Key<D>(offset=1912, nElements=1)),
#     (Field['Flag'](name="ext_convolved_ConvolvedFlux_3_4_5_flag_apCorr", doc="set if unable to aperture correct ext_convolved_ConvolvedFlux_3_4_5"), Key['Flag'](offset=1688, bit=15)),
#     (Field['D'](name="ext_convolved_ConvolvedFlux_0_6_0_apCorr", doc="aperture correction applied to ext_convolved_ConvolvedFlux_0_6_0"), Key<D>(offset=1920, nElements=1)),
#     (Field['D'](name="ext_convolved_ConvolvedFlux_0_6_0_apCorrSigma", doc="aperture correction applied to ext_convolved_ConvolvedFlux_0_6_0"), Key<D>(offset=1928, nElements=1)),
#     (Field['Flag'](name="ext_convolved_ConvolvedFlux_0_6_0_flag_apCorr", doc="set if unable to aperture correct ext_convolved_ConvolvedFlux_0_6_0"), Key['Flag'](offset=1688, bit=16)),
#     (Field['D'](name="ext_convolved_ConvolvedFlux_3_6_0_apCorr", doc="aperture correction applied to ext_convolved_ConvolvedFlux_3_6_0"), Key<D>(offset=1936, nElements=1)),
#     (Field['D'](name="ext_convolved_ConvolvedFlux_3_6_0_apCorrSigma", doc="aperture correction applied to ext_convolved_ConvolvedFlux_3_6_0"), Key<D>(offset=1944, nElements=1)),
#     (Field['Flag'](name="ext_convolved_ConvolvedFlux_3_6_0_flag_apCorr", doc="set if unable to aperture correct ext_convolved_ConvolvedFlux_3_6_0"), Key['Flag'](offset=1688, bit=17)),
#     (Field['D'](name="ext_convolved_ConvolvedFlux_1_3_3_apCorr", doc="aperture correction applied to ext_convolved_ConvolvedFlux_1_3_3"), Key<D>(offset=1952, nElements=1)),
#     (Field['D'](name="ext_convolved_ConvolvedFlux_1_3_3_apCorrSigma", doc="aperture correction applied to ext_convolved_ConvolvedFlux_1_3_3"), Key<D>(offset=1960, nElements=1)),
#     (Field['Flag'](name="ext_convolved_ConvolvedFlux_1_3_3_flag_apCorr", doc="set if unable to aperture correct ext_convolved_ConvolvedFlux_1_3_3"), Key['Flag'](offset=1688, bit=18)),
#     (Field['D'](name="ext_convolved_ConvolvedFlux_2_kron_apCorr", doc="aperture correction applied to ext_convolved_ConvolvedFlux_2_kron"), Key<D>(offset=1968, nElements=1)),
#     (Field['D'](name="ext_convolved_ConvolvedFlux_2_kron_apCorrSigma", doc="aperture correction applied to ext_convolved_ConvolvedFlux_2_kron"), Key<D>(offset=1976, nElements=1)),
#     (Field['Flag'](name="ext_convolved_ConvolvedFlux_2_kron_flag_apCorr", doc="set if unable to aperture correct ext_convolved_ConvolvedFlux_2_kron"), Key['Flag'](offset=1688, bit=19)),
#     (Field['D'](name="ext_convolved_ConvolvedFlux_1_4_5_apCorr", doc="aperture correction applied to ext_convolved_ConvolvedFlux_1_4_5"), Key<D>(offset=1984, nElements=1)),
#     (Field['D'](name="ext_convolved_ConvolvedFlux_1_4_5_apCorrSigma", doc="aperture correction applied to ext_convolved_ConvolvedFlux_1_4_5"), Key<D>(offset=1992, nElements=1)),
#     (Field['Flag'](name="ext_convolved_ConvolvedFlux_1_4_5_flag_apCorr", doc="set if unable to aperture correct ext_convolved_ConvolvedFlux_1_4_5"), Key['Flag'](offset=1688, bit=20)),
#     (Field['D'](name="ext_convolved_ConvolvedFlux_2_6_0_apCorr", doc="aperture correction applied to ext_convolved_ConvolvedFlux_2_6_0"), Key<D>(offset=2000, nElements=1)),
#     (Field['D'](name="ext_convolved_ConvolvedFlux_2_6_0_apCorrSigma", doc="aperture correction applied to ext_convolved_ConvolvedFlux_2_6_0"), Key<D>(offset=2008, nElements=1)),
#     (Field['Flag'](name="ext_convolved_ConvolvedFlux_2_6_0_flag_apCorr", doc="set if unable to aperture correct ext_convolved_ConvolvedFlux_2_6_0"), Key['Flag'](offset=1688, bit=21)),
#     (Field['D'](name="base_GaussianFlux_apCorr", doc="aperture correction applied to base_GaussianFlux"), Key<D>(offset=2016, nElements=1)),
#     (Field['D'](name="base_GaussianFlux_apCorrSigma", doc="aperture correction applied to base_GaussianFlux"), Key<D>(offset=2024, nElements=1)),
#     (Field['Flag'](name="base_GaussianFlux_flag_apCorr", doc="set if unable to aperture correct base_GaussianFlux"), Key['Flag'](offset=1688, bit=22)),
#     (Field['D'](name="modelfit_CModel_exp_apCorr", doc="aperture correction applied to modelfit_CModel_exp"), Key<D>(offset=2032, nElements=1)),
#     (Field['D'](name="modelfit_CModel_exp_apCorrSigma", doc="aperture correction applied to modelfit_CModel_exp"), Key<D>(offset=2040, nElements=1)),
#     (Field['Flag'](name="modelfit_CModel_exp_flag_apCorr", doc="set if unable to aperture correct modelfit_CModel_exp"), Key['Flag'](offset=1688, bit=23)),
#     (Field['D'](name="base_ClassificationExtendedness_value", doc="Set to 1 for extended sources, 0 for point sources."), Key<D>(offset=2048, nElements=1)),
#     (Field['Flag'](name="base_ClassificationExtendedness_flag", doc="Set to 1 for any fatal failure."), Key['Flag'](offset=1688, bit=24)),
#     (Field['I'](name="base_FootprintArea_value", doc="Number of pixels in the source''s detection footprint.", units="pixel"), Key<I>(offset=2056, nElements=1)),
#     'base_CircularApertureFlux_flag_badCentroid'->'base_SdssCentroid_flag'
#     'base_GaussianCentroid_flag_badInitialCentroid'->'base_SdssCentroid_flag'
#     'base_GaussianFlux_flag_badCentroid'->'base_SdssCentroid_flag'
#     'base_GaussianFlux_flag_badShape'->'ext_shapeHSM_HsmSourceMoments_flag'
#     'base_InputCount_flag_badCentroid'->'base_SdssCentroid_flag'
#     'base_NaiveCentroid_flag_badInitialCentroid'->'base_SdssCentroid_flag'
#     'base_PsfFlux_flag_badCentroid'->'base_SdssCentroid_flag'
#     'base_SdssShape_flag_badCentroid'->'base_SdssCentroid_flag'
#     'base_Variance_flag_badCentroid'->'base_SdssCentroid_flag'
#     'ext_convolved_ConvolvedFlux_0_flag_badCentroid'->'base_SdssCentroid_flag'
#     'ext_convolved_ConvolvedFlux_1_flag_badCentroid'->'base_SdssCentroid_flag'
#     'ext_convolved_ConvolvedFlux_2_flag_badCentroid'->'base_SdssCentroid_flag'
#     'ext_convolved_ConvolvedFlux_3_flag_badCentroid'->'base_SdssCentroid_flag'
#     'ext_convolved_ConvolvedFlux_flag_badCentroid'->'base_SdssCentroid_flag'
#     'ext_shapeHSM_HsmPsfMoments_flag_badCentroid'->'base_SdssCentroid_flag'
#     'ext_shapeHSM_HsmShapeBj_flag_badCentroid'->'base_SdssCentroid_flag'
#     'ext_shapeHSM_HsmShapeKsb_flag_badCentroid'->'base_SdssCentroid_flag'
#     'ext_shapeHSM_HsmShapeLinear_flag_badCentroid'->'base_SdssCentroid_flag'
#     'ext_shapeHSM_HsmShapeRegauss_flag_badCentroid'->'base_SdssCentroid_flag'
#     'ext_shapeHSM_HsmSourceMoments_flag_badCentroid'->'base_SdssCentroid_flag'
#     'modelfit_DoubleShapeletPsfApprox_flag_badCentroid'->'base_SdssCentroid_flag'
#     'slot_ApFlux'->'base_CircularApertureFlux_12_0'
#     'slot_CalibFlux'->'base_CircularApertureFlux_12_0'
#     'slot_Centroid'->'base_SdssCentroid'
#     'slot_InstFlux'->'base_GaussianFlux'
#     'slot_ModelFlux'->'modelfit_CModel'
#     'slot_PsfFlux'->'base_PsfFlux'
#     'slot_PsfShape'->'base_SdssShape_psf'
#     'slot_Shape'->'ext_shapeHSM_HsmSourceMoments'
# )

# %%
a.keys()
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-75-27ddd10295a4> in <module>()
# ----> 1 a.keys()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'keys'

# %%
par = but.repoData.getParentRepoDatas()[0]

# %%
par.cfgRoot

# %%
import os

# %%
os.path.realpath(par.cfgRoot)

# %%
but.datasetTypes[0]

# %%
toto = []

# %%
for dataset in but.datasetTypes:
    try:
        bb = but.butler.get(dataset, dataId=but.dataIds['raw'][0])
        toto.append([dataset, bb])
        print("data found for", dataset)
    except:
        continue

# %%
toto

# %%
configs = [ds for ds in but.datasetTypes if ds.endswith("_config")]

# %%
configs[0]

# %%
cfg = but.butler.get('singleFrameDriver_config', dataId=but.dataIds['raw'][0]).toDict()

# %%
cfg.keys()

# %%
cfg['processCcd']

# %%
vds = {}
for dataset in but.datasetTypes:
    try:
        try:
            if but.butler.datasetExists(dataset, dataId=but.dataIds['raw'][0]):
                vds[dataset] = but.dataIds['raw'][0]
        except:
            pass
        try:
            if but.butler.datasetExists(dataset, dataId=but.dataIds['deepCoadd_meas'][0]):
                vds[dataset] = but.dataIds['deepCoadd_meas'][0]
        except:
            pass
        try:
            if but.butler.datasetExists(dataset):
                vds[dataset] = ''
        except:
            pass
        if dataset not in vds:
            print(dataset)
        #but.butler.get(dataset, dataId=but.dataIds['raw'][0])
    except:
        pass

# %%
vds, len(vds), len(but.datasetTypes)

# %%
vds

# %%
sc = but.butler.get('deepCoadd_forced_src_schema', dataId=but.dataIds['deepCoadd_forced_src'][0])

# %%
sc.asAstropy()

# %%
configs = {}
for dataset in but.datasetTypes:
    if not dataset.endswith('_config'):
        continue
    try:
        if but.butler.datasetExists(dataset, dataId=but.dataIds['raw'][0]):
            configs[dataset] = but.dataIds['raw'][0]
    except:
        pass
    try:
        if but.butler.datasetExists(dataset, dataId=but.dataIds['deepCoadd_meas'][0]):
            configd[dataset] = but.dataIds['deepCoadd_meas'][0]
    except:
        pass
    try:
        if but.butler.datasetExists(dataset):
            configs[dataset] = ''
    except:
        pass
    if dataset not in configs:
        print(dataset, "not found")

# %%
configs

# %%
cfg = but.butler.get('forcedPhotCcd_config')

# %%
cfg.toDict().keys()

# %%
schema = {}
for dataset in but.datasetTypes:
    if not dataset.endswith('_schema'):
        continue
    try:
        if but.butler.datasetExists(dataset):
            schema[dataset] = ''
    except:
        pass
    if dataset not in configs:
        print(dataset, "not found")

# %%
schema

# %%
datatype = {}
for dataset in but.datasetTypes:
    if not dataset.endswith('_%s' % "config"):
        continue
    print(dataset)
    try:
        datatype[dataset] = but.butler.get(dataset)
    except:
        pass
# Out:
# IngestIndexedReferenceTask_config
# Mosaic_config
# bias_config
# calibrate_config
# characterizeImage_config
# coaddDriver_config
# dark_config
# dcrCoadd_forced_config
# deepCoadd_forced_config
# deepDiff_config
# deep_assembleCoadd_config
# deep_compareWarpAssembleCoadd_config
# deep_makeCoaddTempExp_config
# deep_makeSkyMap_config
# deep_safeClipAssembleCoadd_config
# detectCoaddSources_config
# donutDriver_config
# fitDonut_config
# flat_config
# forcedCcd_config
# forcedPhotCcd_config
# forcedPhotCoadd_config
# fringe_config
# isr_config
# measureCoaddSources_config
# mergeCoaddDetections_config
# mergeCoaddMeasurements_config
# multiBandDriver_config
# processCcd_config
# ref_cat_config
# singleFrameDriver_config
# skyCorr_config
# sky_config
# transformSrcMeasurement_config

# %%
datatype
# Out:
# {'dcrCoadd_forced_config': lsst.meas.base.forcedPhotCoadd.ForcedPhotCoaddConfig(references={'removePatchOverlaps': False, 'filter': None, 'coaddName': 'deep', 'skipMissing': False}, measurement={'slots': {'centroid': 'base_TransformedCentroid', 'shape': 'base_TransformedShape', 'psfShape': 'base_SdssShape_psf', 'apFlux': None, 'modelFlux': 'modelfit_CModel', 'psfFlux': None, 'instFlux': None, 'calibFlux': None}, 'doReplaceWithNoise': True, 'noiseReplacer': {'noiseSource': 'measure', 'noiseOffset': 0.0, 'noiseSeedMultiplier': 1}, 'undeblendedPrefix': 'undeblended_', 'plugins': {'names': ['base_PixelFlags', 'modelfit_CModel', 'modelfit_DoubleShapeletPsfApprox', 'base_PsfFlux', 'base_GaussianFlux', 'base_TransformedCentroid', 'base_TransformedShape', 'modelfit_GeneralShapeletPsfApprox', 'base_Variance', 'base_CircularApertureFlux', 'base_InputCount'], 'values': {'base_PsfFlux': {'doMeasure': True, 'badMaskPlanes': []}, 'base_PeakLikelihoodFlux': {'doMeasure': True, 'warpingKernelName': 'lanczos4'}, 'base_GaussianFlux': {'doMeasure': True, 'background': 0.0}, 'base_GaussianCentroid': {'doMeasure': True, 'doFootprintCheck': True, 'maxDistToPeak': -1.0}, 'base_NaiveCentroid': {'doMeasure': True, 'background': 0.0, 'doFootprintCheck': True, 'maxDistToPeak': -1.0}, 'base_SdssCentroid': {'doMeasure': True, 'binmax': 16, 'doFootprintCheck': True, 'maxDistToPeak': -1.0, 'peakMin': -1.0, 'wfac': 1.5}, 'base_PixelFlags': {'doMeasure': True, 'masksFpAnywhere': ['CLIPPED', 'SENSOR_EDGE', 'INEXACT_PSF'], 'masksFpCenter': []}, 'base_SdssShape': {'doMeasure': True, 'background': 0.0, 'doMeasurePsf': True, 'maxIter': 100, 'maxShift': 0.0, 'tol1': 9.999999747378752e-06, 'tol2': 9.999999747378752e-05}, 'base_ScaledApertureFlux': {'doMeasure': True, 'scale': 3.14, 'shiftKernel': 'lanczos5'}, 'base_CircularApertureFlux': {'doMeasure': True, 'maxSincRadius': 10.0, 'radii': [3.0, 4.5, 6.0, 9.0, 12.0, 17.0, 25.0, 35.0, 50.0, 70.0], 'shiftKernel': 'lanczos5'}, 'base_Blendedness': {'doMeasure': True, 'doFlux': True, 'doOld': True, 'doShape': True, 'nSigmaWeightMax': 3.0}, 'base_Variance': {'doMeasure': True, 'scale': 5.0, 'mask': ['DETECTED', 'DETECTED_NEGATIVE', 'BAD', 'SAT']}, 'base_InputCount': {'doMeasure': True}, 'base_PeakCentroid': {'doMeasure': True}, 'base_TransformedCentroid': {'doMeasure': True}, 'base_TransformedShape': {'doMeasure': True}, 'modelfit_DoubleShapeletPsfApprox': {'doMeasure': True, 'innerOrder': 2, 'maxRadiusBoxFraction': 0.4, 'minRadius': 1.0, 'minRadiusDiff': 0.5, 'optimizer': {'doSaveIterations': False, 'gradientThreshold': 1e-05, 'maxInnerIterations': 20, 'maxOuterIterations': 500, 'minTrustRadiusThreshold': 1e-05, 'noSR1Term': False, 'numDiffAbsStep': 0.0, 'numDiffRelStep': 0.0, 'numDiffTrustRadiusStep': 0.1, 'skipSR1UpdateThreshold': 1e-08, 'stepAcceptThreshold': 0.0, 'trustRegionGrowFactor': 2.0, 'trustRegionGrowReductionRatio': 0.75, 'trustRegionGrowStepFraction': 0.8, 'trustRegionInitialSize': 1.0, 'trustRegionShrinkFactor': 0.3333333333333333, 'trustRegionShrinkReductionRatio': 0.25, 'trustRegionSolverTolerance': 1e-08}, 'outerOrder': 1, 'peakRatio': 0.1, 'radiusRatio': 2.0}, 'modelfit_GeneralShapeletPsfApprox': {'models': {'SingleGaussian': {'defaultNoiseSigma': 0.001, 'inner': {'ellipticityPriorSigma': 0.3, 'order': -1, 'positionPriorSigma': 0.1, 'radiusFactor': 0.5, 'radiusPriorSigma': 0.5}, 'optimizer': {'doSaveIterations': False, 'gradientThreshold': 1e-05, 'maxInnerIterations': 20, 'maxOuterIterations': 500, 'minTrustRadiusThreshold': 1e-05, 'noSR1Term': False, 'numDiffAbsStep': 0.0, 'numDiffRelStep': 0.0, 'numDiffTrustRadiusStep': 0.1, 'skipSR1UpdateThreshold': 1e-08, 'stepAcceptThreshold': 0.0, 'trustRegionGrowFactor': 2.0, 'trustRegionGrowReductionRatio': 0.75, 'trustRegionGrowStepFraction': 0.8, 'trustRegionInitialSize': 1.0, 'trustRegionShrinkFactor': 0.3333333333333333, 'trustRegionShrinkReductionRatio': 0.25, 'trustRegionSolverTolerance': 1e-08}, 'outer': {'ellipticityPriorSigma': 0.3, 'order': -1, 'positi ...
#  'deepCoadd_forced_config': lsst.meas.base.forcedPhotCoadd.ForcedPhotCoaddConfig(references={'removePatchOverlaps': False, 'filter': None, 'coaddName': 'deep', 'skipMissing': False}, measurement={'slots': {'centroid': 'base_TransformedCentroid', 'shape': 'base_TransformedShape', 'psfShape': 'base_SdssShape_psf', 'apFlux': None, 'modelFlux': 'modelfit_CModel', 'psfFlux': None, 'instFlux': None, 'calibFlux': None}, 'doReplaceWithNoise': True, 'noiseReplacer': {'noiseSource': 'measure', 'noiseOffset': 0.0, 'noiseSeedMultiplier': 1}, 'undeblendedPrefix': 'undeblended_', 'plugins': {'names': ['base_PixelFlags', 'modelfit_CModel', 'modelfit_DoubleShapeletPsfApprox', 'base_PsfFlux', 'base_GaussianFlux', 'base_TransformedCentroid', 'base_TransformedShape', 'modelfit_GeneralShapeletPsfApprox', 'base_Variance', 'base_CircularApertureFlux', 'base_InputCount'], 'values': {'base_PsfFlux': {'doMeasure': True, 'badMaskPlanes': []}, 'base_PeakLikelihoodFlux': {'doMeasure': True, 'warpingKernelName': 'lanczos4'}, 'base_GaussianFlux': {'doMeasure': True, 'background': 0.0}, 'base_GaussianCentroid': {'doMeasure': True, 'doFootprintCheck': True, 'maxDistToPeak': -1.0}, 'base_NaiveCentroid': {'doMeasure': True, 'background': 0.0, 'doFootprintCheck': True, 'maxDistToPeak': -1.0}, 'base_SdssCentroid': {'doMeasure': True, 'binmax': 16, 'doFootprintCheck': True, 'maxDistToPeak': -1.0, 'peakMin': -1.0, 'wfac': 1.5}, 'base_PixelFlags': {'doMeasure': True, 'masksFpAnywhere': ['CLIPPED', 'SENSOR_EDGE', 'INEXACT_PSF'], 'masksFpCenter': []}, 'base_SdssShape': {'doMeasure': True, 'background': 0.0, 'doMeasurePsf': True, 'maxIter': 100, 'maxShift': 0.0, 'tol1': 9.999999747378752e-06, 'tol2': 9.999999747378752e-05}, 'base_ScaledApertureFlux': {'doMeasure': True, 'scale': 3.14, 'shiftKernel': 'lanczos5'}, 'base_CircularApertureFlux': {'doMeasure': True, 'maxSincRadius': 10.0, 'radii': [3.0, 4.5, 6.0, 9.0, 12.0, 17.0, 25.0, 35.0, 50.0, 70.0], 'shiftKernel': 'lanczos5'}, 'base_Blendedness': {'doMeasure': True, 'doFlux': True, 'doOld': True, 'doShape': True, 'nSigmaWeightMax': 3.0}, 'base_Variance': {'doMeasure': True, 'scale': 5.0, 'mask': ['DETECTED', 'DETECTED_NEGATIVE', 'BAD', 'SAT']}, 'base_InputCount': {'doMeasure': True}, 'base_PeakCentroid': {'doMeasure': True}, 'base_TransformedCentroid': {'doMeasure': True}, 'base_TransformedShape': {'doMeasure': True}, 'modelfit_DoubleShapeletPsfApprox': {'doMeasure': True, 'innerOrder': 2, 'maxRadiusBoxFraction': 0.4, 'minRadius': 1.0, 'minRadiusDiff': 0.5, 'optimizer': {'doSaveIterations': False, 'gradientThreshold': 1e-05, 'maxInnerIterations': 20, 'maxOuterIterations': 500, 'minTrustRadiusThreshold': 1e-05, 'noSR1Term': False, 'numDiffAbsStep': 0.0, 'numDiffRelStep': 0.0, 'numDiffTrustRadiusStep': 0.1, 'skipSR1UpdateThreshold': 1e-08, 'stepAcceptThreshold': 0.0, 'trustRegionGrowFactor': 2.0, 'trustRegionGrowReductionRatio': 0.75, 'trustRegionGrowStepFraction': 0.8, 'trustRegionInitialSize': 1.0, 'trustRegionShrinkFactor': 0.3333333333333333, 'trustRegionShrinkReductionRatio': 0.25, 'trustRegionSolverTolerance': 1e-08}, 'outerOrder': 1, 'peakRatio': 0.1, 'radiusRatio': 2.0}, 'modelfit_GeneralShapeletPsfApprox': {'models': {'SingleGaussian': {'defaultNoiseSigma': 0.001, 'inner': {'ellipticityPriorSigma': 0.3, 'order': -1, 'positionPriorSigma': 0.1, 'radiusFactor': 0.5, 'radiusPriorSigma': 0.5}, 'optimizer': {'doSaveIterations': False, 'gradientThreshold': 1e-05, 'maxInnerIterations': 20, 'maxOuterIterations': 500, 'minTrustRadiusThreshold': 1e-05, 'noSR1Term': False, 'numDiffAbsStep': 0.0, 'numDiffRelStep': 0.0, 'numDiffTrustRadiusStep': 0.1, 'skipSR1UpdateThreshold': 1e-08, 'stepAcceptThreshold': 0.0, 'trustRegionGrowFactor': 2.0, 'trustRegionGrowReductionRatio': 0.75, 'trustRegionGrowStepFraction': 0.8, 'trustRegionInitialSize': 1.0, 'trustRegionShrinkFactor': 0.3333333333333333, 'trustRegionShrinkReductionRatio': 0.25, 'trustRegionSolverTolerance': 1e-08}, 'outer': {'ellipticityPriorSigma': 0.3, 'order': -1, 'posit ...
#  'detectCoaddSources_config': lsst.pipe.tasks.multiBand.DetectCoaddSourcesConfig(doScaleVariance=True, detection={'minPixels': 1, 'isotropicGrow': True, 'nSigmaToGrow': 2.4, 'returnOriginalFootprints': False, 'thresholdValue': 5.0, 'includeThresholdMultiplier': 1.0, 'thresholdType': 'pixel_stdev', 'thresholdPolarity': 'positive', 'adjustBackground': 0.0, 'reEstimateBackground': True, 'background': {'statisticsProperty': 'MEANCLIP', 'undersampleStyle': 'REDUCE_INTERP_ORDER', 'binSize': 4096, 'binSizeX': 0, 'binSizeY': 0, 'algorithm': 'AKIMA_SPLINE', 'ignoredPixelMask': ['BAD', 'EDGE', 'DETECTED', 'DETECTED_NEGATIVE', 'NO_DATA'], 'isNanSafe': False, 'useApprox': False, 'approxOrderX': 6, 'approxOrderY': -1, 'weighting': True}, 'tempLocalBackground': {'statisticsProperty': 'MEANCLIP', 'undersampleStyle': 'REDUCE_INTERP_ORDER', 'binSize': 64, 'binSizeX': 0, 'binSizeY': 0, 'algorithm': 'AKIMA_SPLINE', 'ignoredPixelMask': ['BAD', 'EDGE', 'DETECTED', 'DETECTED_NEGATIVE', 'NO_DATA'], 'isNanSafe': False, 'useApprox': False, 'approxOrderX': 6, 'approxOrderY': -1, 'weighting': True}, 'doTempLocalBackground': True, 'nPeaksMaxSimple': 1}, coaddName='deep', mask=['DETECTED', 'BAD', 'SAT', 'NO_DATA', 'INTRP'], doInsertFakes=False, insertFakes={'maskPlaneName': 'FAKE'}),
#  'forcedPhotCcd_config': lsst.meas.base.forcedPhotCcd.ForcedPhotCcdConfig(references={'removePatchOverlaps': True, 'filter': None, 'coaddName': 'deep', 'skipMissing': False}, measurement={'slots': {'centroid': 'base_TransformedCentroid', 'shape': 'ext_shapeHSM_HsmSourceMoments', 'psfShape': 'base_SdssShape_psf', 'apFlux': None, 'modelFlux': 'base_GaussianFlux', 'psfFlux': None, 'instFlux': None, 'calibFlux': None}, 'doReplaceWithNoise': True, 'noiseReplacer': {'noiseSource': 'measure', 'noiseOffset': 0.0, 'noiseSeedMultiplier': 1}, 'undeblendedPrefix': 'undeblended_', 'plugins': {'names': ['base_PsfFlux', 'ext_shapeHSM_HsmShapeRegauss', 'base_GaussianFlux', 'base_CircularApertureFlux', 'ext_shapeHSM_HsmSourceMoments', 'base_TransformedCentroid', 'ext_shapeHSM_HsmPsfMoments', 'base_TransformedShape', 'base_PixelFlags'], 'values': {'base_PsfFlux': {'doMeasure': True, 'badMaskPlanes': []}, 'base_PeakLikelihoodFlux': {'doMeasure': True, 'warpingKernelName': 'lanczos4'}, 'base_GaussianFlux': {'doMeasure': True, 'background': 0.0}, 'base_GaussianCentroid': {'doMeasure': True, 'doFootprintCheck': True, 'maxDistToPeak': -1.0}, 'base_NaiveCentroid': {'doMeasure': True, 'background': 0.0, 'doFootprintCheck': True, 'maxDistToPeak': -1.0}, 'base_SdssCentroid': {'doMeasure': True, 'binmax': 16, 'doFootprintCheck': True, 'maxDistToPeak': -1.0, 'peakMin': -1.0, 'wfac': 1.5}, 'base_PixelFlags': {'doMeasure': True, 'masksFpAnywhere': [], 'masksFpCenter': []}, 'base_SdssShape': {'doMeasure': True, 'background': 0.0, 'doMeasurePsf': True, 'maxIter': 100, 'maxShift': 0.0, 'tol1': 9.999999747378752e-06, 'tol2': 9.999999747378752e-05}, 'base_ScaledApertureFlux': {'doMeasure': True, 'scale': 3.14, 'shiftKernel': 'lanczos5'}, 'base_CircularApertureFlux': {'doMeasure': True, 'maxSincRadius': 10.0, 'radii': [3.0, 4.5, 6.0, 9.0, 12.0, 17.0, 25.0, 35.0, 50.0, 70.0], 'shiftKernel': 'lanczos5'}, 'base_Blendedness': {'doMeasure': True, 'doFlux': True, 'doOld': True, 'doShape': True, 'nSigmaWeightMax': 3.0}, 'base_Variance': {'doMeasure': True, 'scale': 5.0, 'mask': ['DETECTED', 'DETECTED_NEGATIVE', 'BAD', 'SAT']}, 'base_InputCount': {'doMeasure': True}, 'base_PeakCentroid': {'doMeasure': True}, 'base_TransformedCentroid': {'doMeasure': True}, 'base_TransformedShape': {'doMeasure': True}, 'modelfit_DoubleShapeletPsfApprox': {'doMeasure': True, 'innerOrder': 2, 'maxRadiusBoxFraction': 0.4, 'minRadius': 1.0, 'minRadiusDiff': 0.5, 'optimizer': {'doSaveIterations': False, 'gradientThreshold': 1e-05, 'maxInnerIterations': 20, 'maxOuterIterations': 500, 'minTrustRadiusThreshold': 1e-05, 'noSR1Term': False, 'numDiffAbsStep': 0.0, 'numDiffRelStep': 0.0, 'numDiffTrustRadiusStep': 0.1, 'skipSR1UpdateThreshold': 1e-08, 'stepAcceptThreshold': 0.0, 'trustRegionGrowFactor': 2.0, 'trustRegionGrowReductionRatio': 0.75, 'trustRegionGrowStepFraction': 0.8, 'trustRegionInitialSize': 1.0, 'trustRegionShrinkFactor': 0.3333333333333333, 'trustRegionShrinkReductionRatio': 0.25, 'trustRegionSolverTolerance': 1e-08}, 'outerOrder': 1, 'peakRatio': 0.1, 'radiusRatio': 2.0}, 'modelfit_GeneralShapeletPsfApprox': {'models': {'SingleGaussian': {'defaultNoiseSigma': 0.001, 'inner': {'ellipticityPriorSigma': 0.3, 'order': -1, 'positionPriorSigma': 0.1, 'radiusFactor': 0.5, 'radiusPriorSigma': 0.5}, 'optimizer': {'doSaveIterations': False, 'gradientThreshold': 1e-05, 'maxInnerIterations': 20, 'maxOuterIterations': 500, 'minTrustRadiusThreshold': 1e-05, 'noSR1Term': False, 'numDiffAbsStep': 0.0, 'numDiffRelStep': 0.0, 'numDiffTrustRadiusStep': 0.1, 'skipSR1UpdateThreshold': 1e-08, 'stepAcceptThreshold': 0.0, 'trustRegionGrowFactor': 2.0, 'trustRegionGrowReductionRatio': 0.75, 'trustRegionGrowStepFraction': 0.8, 'trustRegionInitialSize': 1.0, 'trustRegionShrinkFactor': 0.3333333333333333, 'trustRegionShrinkReductionRatio': 0.25, 'trustRegionSolverTolerance': 1e-08}, 'outer': {'ellipticityPriorSigma': 0.3, 'order': -1, 'positionPriorSigma': 0.1, 'radiusFactor': 4.0, 'radiusPriorSigma': 0.5}, 'p ...
#  'forcedPhotCoadd_config': lsst.meas.base.forcedPhotCoadd.ForcedPhotCoaddConfig(references={'removePatchOverlaps': False, 'filter': None, 'coaddName': 'deep', 'skipMissing': False}, measurement={'slots': {'centroid': 'base_TransformedCentroid', 'shape': 'base_TransformedShape', 'psfShape': 'base_SdssShape_psf', 'apFlux': None, 'modelFlux': 'modelfit_CModel', 'psfFlux': None, 'instFlux': None, 'calibFlux': None}, 'doReplaceWithNoise': True, 'noiseReplacer': {'noiseSource': 'measure', 'noiseOffset': 0.0, 'noiseSeedMultiplier': 1}, 'undeblendedPrefix': 'undeblended_', 'plugins': {'names': ['base_PixelFlags', 'modelfit_CModel', 'modelfit_DoubleShapeletPsfApprox', 'base_PsfFlux', 'base_GaussianFlux', 'base_TransformedCentroid', 'base_TransformedShape', 'modelfit_GeneralShapeletPsfApprox', 'base_Variance', 'base_CircularApertureFlux', 'base_InputCount'], 'values': {'base_PsfFlux': {'doMeasure': True, 'badMaskPlanes': []}, 'base_PeakLikelihoodFlux': {'doMeasure': True, 'warpingKernelName': 'lanczos4'}, 'base_GaussianFlux': {'doMeasure': True, 'background': 0.0}, 'base_GaussianCentroid': {'doMeasure': True, 'doFootprintCheck': True, 'maxDistToPeak': -1.0}, 'base_NaiveCentroid': {'doMeasure': True, 'background': 0.0, 'doFootprintCheck': True, 'maxDistToPeak': -1.0}, 'base_SdssCentroid': {'doMeasure': True, 'binmax': 16, 'doFootprintCheck': True, 'maxDistToPeak': -1.0, 'peakMin': -1.0, 'wfac': 1.5}, 'base_PixelFlags': {'doMeasure': True, 'masksFpAnywhere': ['CLIPPED', 'SENSOR_EDGE', 'INEXACT_PSF'], 'masksFpCenter': []}, 'base_SdssShape': {'doMeasure': True, 'background': 0.0, 'doMeasurePsf': True, 'maxIter': 100, 'maxShift': 0.0, 'tol1': 9.999999747378752e-06, 'tol2': 9.999999747378752e-05}, 'base_ScaledApertureFlux': {'doMeasure': True, 'scale': 3.14, 'shiftKernel': 'lanczos5'}, 'base_CircularApertureFlux': {'doMeasure': True, 'maxSincRadius': 10.0, 'radii': [3.0, 4.5, 6.0, 9.0, 12.0, 17.0, 25.0, 35.0, 50.0, 70.0], 'shiftKernel': 'lanczos5'}, 'base_Blendedness': {'doMeasure': True, 'doFlux': True, 'doOld': True, 'doShape': True, 'nSigmaWeightMax': 3.0}, 'base_Variance': {'doMeasure': True, 'scale': 5.0, 'mask': ['DETECTED', 'DETECTED_NEGATIVE', 'BAD', 'SAT']}, 'base_InputCount': {'doMeasure': True}, 'base_PeakCentroid': {'doMeasure': True}, 'base_TransformedCentroid': {'doMeasure': True}, 'base_TransformedShape': {'doMeasure': True}, 'modelfit_DoubleShapeletPsfApprox': {'doMeasure': True, 'innerOrder': 2, 'maxRadiusBoxFraction': 0.4, 'minRadius': 1.0, 'minRadiusDiff': 0.5, 'optimizer': {'doSaveIterations': False, 'gradientThreshold': 1e-05, 'maxInnerIterations': 20, 'maxOuterIterations': 500, 'minTrustRadiusThreshold': 1e-05, 'noSR1Term': False, 'numDiffAbsStep': 0.0, 'numDiffRelStep': 0.0, 'numDiffTrustRadiusStep': 0.1, 'skipSR1UpdateThreshold': 1e-08, 'stepAcceptThreshold': 0.0, 'trustRegionGrowFactor': 2.0, 'trustRegionGrowReductionRatio': 0.75, 'trustRegionGrowStepFraction': 0.8, 'trustRegionInitialSize': 1.0, 'trustRegionShrinkFactor': 0.3333333333333333, 'trustRegionShrinkReductionRatio': 0.25, 'trustRegionSolverTolerance': 1e-08}, 'outerOrder': 1, 'peakRatio': 0.1, 'radiusRatio': 2.0}, 'modelfit_GeneralShapeletPsfApprox': {'models': {'SingleGaussian': {'defaultNoiseSigma': 0.001, 'inner': {'ellipticityPriorSigma': 0.3, 'order': -1, 'positionPriorSigma': 0.1, 'radiusFactor': 0.5, 'radiusPriorSigma': 0.5}, 'optimizer': {'doSaveIterations': False, 'gradientThreshold': 1e-05, 'maxInnerIterations': 20, 'maxOuterIterations': 500, 'minTrustRadiusThreshold': 1e-05, 'noSR1Term': False, 'numDiffAbsStep': 0.0, 'numDiffRelStep': 0.0, 'numDiffTrustRadiusStep': 0.1, 'skipSR1UpdateThreshold': 1e-08, 'stepAcceptThreshold': 0.0, 'trustRegionGrowFactor': 2.0, 'trustRegionGrowReductionRatio': 0.75, 'trustRegionGrowStepFraction': 0.8, 'trustRegionInitialSize': 1.0, 'trustRegionShrinkFactor': 0.3333333333333333, 'trustRegionShrinkReductionRatio': 0.25, 'trustRegionSolverTolerance': 1e-08}, 'outer': {'ellipticityPriorSigma': 0.3, 'order': -1, 'positi ...
#  'measureCoaddSources_config': lsst.pipe.tasks.multiBand.MeasureMergedCoaddSourcesConfig(doDeblend=True, deblend={'edgeHandling': 'ramp', 'strayFluxToPointSources': 'necessary', 'assignStrayFlux': True, 'strayFluxRule': 'trim', 'clipStrayFluxFraction': 0.001, 'psfChisq1': 1.5, 'psfChisq2': 1.5, 'psfChisq2b': 1.5, 'maxNumberOfPeaks': 0, 'maxFootprintArea': 1000000, 'maxFootprintSize': 2000, 'minFootprintAxisRatio': 0.0, 'notDeblendedMask': 'NOT_DEBLENDED', 'tinyFootprintSize': 2, 'propagateAllPeaks': True, 'catchFailures': False, 'maskPlanes': ['SAT', 'INTRP', 'NO_DATA'], 'maskLimits': {}, 'weightTemplates': False, 'removeDegenerateTemplates': False, 'maxTempDotProd': 0.5, 'medianSmoothTemplate': True}, measurement={'slots': {'centroid': 'base_SdssCentroid', 'shape': 'ext_shapeHSM_HsmSourceMoments', 'psfShape': 'base_SdssShape_psf', 'apFlux': 'base_CircularApertureFlux_12_0', 'modelFlux': 'modelfit_CModel', 'psfFlux': 'base_PsfFlux', 'instFlux': 'base_GaussianFlux', 'calibFlux': 'base_CircularApertureFlux_12_0'}, 'doReplaceWithNoise': True, 'noiseReplacer': {'noiseSource': 'measure', 'noiseOffset': 0.0, 'noiseSeedMultiplier': 1}, 'undeblendedPrefix': 'undeblended_', 'plugins': {'names': ['ext_shapeHSM_HsmShapeLinear', 'base_NaiveCentroid', 'ext_shapeHSM_HsmShapeKsb', 'base_SdssCentroid', 'ext_shapeHSM_HsmSourceMoments', 'ext_shapeHSM_HsmPsfMoments', 'modelfit_CModel', 'base_SdssShape', 'base_Variance', 'base_CircularApertureFlux', 'base_InputCount', 'base_GaussianCentroid', 'base_PsfFlux', 'modelfit_DoubleShapeletPsfApprox', 'ext_convolved_ConvolvedFlux', 'ext_shapeHSM_HsmShapeRegauss', 'base_GaussianFlux', 'ext_shapeHSM_HsmShapeBj', 'base_SkyCoord', 'base_Blendedness', 'base_PixelFlags'], 'values': {'base_PsfFlux': {'doMeasure': True, 'badMaskPlanes': []}, 'base_PeakLikelihoodFlux': {'doMeasure': True, 'warpingKernelName': 'lanczos4'}, 'base_GaussianFlux': {'doMeasure': True, 'background': 0.0}, 'base_GaussianCentroid': {'doMeasure': True, 'doFootprintCheck': True, 'maxDistToPeak': -1.0}, 'base_NaiveCentroid': {'doMeasure': True, 'background': 0.0, 'doFootprintCheck': True, 'maxDistToPeak': -1.0}, 'base_SdssCentroid': {'doMeasure': True, 'binmax': 16, 'doFootprintCheck': True, 'maxDistToPeak': -1.0, 'peakMin': -1.0, 'wfac': 1.5}, 'base_PixelFlags': {'doMeasure': True, 'masksFpAnywhere': ['CLIPPED', 'SENSOR_EDGE', 'INEXACT_PSF'], 'masksFpCenter': []}, 'base_SdssShape': {'doMeasure': True, 'background': 0.0, 'doMeasurePsf': True, 'maxIter': 100, 'maxShift': 0.0, 'tol1': 9.999999747378752e-06, 'tol2': 9.999999747378752e-05}, 'base_ScaledApertureFlux': {'doMeasure': True, 'scale': 3.14, 'shiftKernel': 'lanczos5'}, 'base_CircularApertureFlux': {'doMeasure': True, 'maxSincRadius': 10.0, 'radii': [3.0, 4.5, 6.0, 9.0, 12.0, 17.0, 25.0, 35.0, 50.0, 70.0], 'shiftKernel': 'lanczos5'}, 'base_Blendedness': {'doMeasure': True, 'doFlux': True, 'doOld': True, 'doShape': True, 'nSigmaWeightMax': 3.0}, 'base_FPPosition': {'doMeasure': True}, 'base_Jacobian': {'doMeasure': True, 'pixelScale': 0.5}, 'base_Variance': {'doMeasure': True, 'scale': 5.0, 'mask': ['DETECTED', 'DETECTED_NEGATIVE', 'BAD', 'SAT']}, 'base_InputCount': {'doMeasure': True}, 'base_PeakCentroid': {'doMeasure': True}, 'base_SkyCoord': {'doMeasure': True}, 'modelfit_DoubleShapeletPsfApprox': {'doMeasure': True, 'innerOrder': 2, 'maxRadiusBoxFraction': 0.4, 'minRadius': 1.0, 'minRadiusDiff': 0.5, 'optimizer': {'doSaveIterations': False, 'gradientThreshold': 1e-05, 'maxInnerIterations': 20, 'maxOuterIterations': 500, 'minTrustRadiusThreshold': 1e-05, 'noSR1Term': False, 'numDiffAbsStep': 0.0, 'numDiffRelStep': 0.0, 'numDiffTrustRadiusStep': 0.1, 'skipSR1UpdateThreshold': 1e-08, 'stepAcceptThreshold': 0.0, 'trustRegionGrowFactor': 2.0, 'trustRegionGrowReductionRatio': 0.75, 'trustRegionGrowStepFraction': 0.8, 'trustRegionInitialSize': 1.0, 'trustRegionShrinkFactor': 0.3333333333333333, 'trustRegionShrinkReductionRatio': 0.25, 'trustRegionSolverTolerance': 1e-08}, 'outerOrder': 1, ' ...
#  'mergeCoaddDetections_config': lsst.pipe.tasks.multiBand.MergeDetectionsConfig(priorityList=['i', 'r', 'z', 'g', 'u'], coaddName='deep', minNewPeak=1.0, maxSamePeak=0.3, cullPeaks={'nBandsSufficient': 2, 'rankSufficient': 20, 'rankConsidered': 30, 'rankNormalizedConsidered': 0.7}, skyFilterName='sky', skySourceRadius=8.0, skyGrowDetectedFootprints=0, nSkySourcesPerPatch=100, nTrialSkySourcesPerPatchMultiplier=5),
#  'mergeCoaddMeasurements_config': lsst.pipe.tasks.multiBand.MergeMeasurementsConfig(priorityList=['i', 'r', 'z', 'g', 'u'], coaddName='deep', pseudoFilterList=['sky'], snName='base_PsfFlux', minSN=10.0, minSNDiff=3.0, flags=['base_PixelFlags_flag_interpolatedCenter', 'base_PsfFlux_flag', 'ext_photometryKron_KronFlux_flag', 'modelfit_CModel_flag']),
#  'singleFrameDriver_config': lsst.pipe.drivers.singleFrameDriver.SingleFrameDriverConfig(processCcd={'isr': {'doBias': False, 'doDark': False, 'doFlat': False, 'doFringe': False, 'doDefect': True, 'doWrite': False, 'assembleCcd': {'doTrim': True, 'keysToRemove': []}, 'gain': nan, 'readNoise': 0.0, 'saturation': nan, 'fringeAfterFlat': False, 'fringe': {'filters': ['i', 'i2', 'z'], 'num': 30000, 'small': 1, 'large': 50, 'iterations': 20, 'clip': 3.0, 'stats': {'badMaskPlanes': ['SAT'], 'stat': 32, 'clip': 3.0, 'iterations': 3, 'rngSeedOffset': 0}, 'pedestal': True}, 'fwhm': 1.0, 'saturatedMaskName': 'SAT', 'suspectMaskName': 'SUSPECT', 'flatScalingType': 'USER', 'flatUserScale': 1.0, 'overscanFitType': 'MEDIAN', 'overscanOrder': 1, 'overscanRej': 3.0, 'growSaturationFootprintSize': 1, 'doSaturationInterpolation': True, 'fluxMag0T1': 10000000000.0, 'keysToRemoveFromAssembledCcd': [], 'doAssembleIsrExposures': True, 'doAssembleCcd': True, 'expectWcs': True, 'doLinearize': True, 'doCrosstalk': False, 'crosstalk': {'minPixelToMask': 45000.0, 'crosstalkMaskPlane': 'CROSSTALK'}, 'doBrighterFatter': False, 'brighterFatterKernelFile': '', 'brighterFatterMaxIter': 10, 'brighterFatterThreshold': 1000.0, 'brighterFatterApplyGain': True, 'datasetType': 'raw', 'fallbackFilterName': None, 'safe': 0.95}, 'charImage': {'doMeasurePsf': True, 'doWrite': True, 'doWriteExposure': False, 'psfIterations': 2, 'background': {'statisticsProperty': 'MEANCLIP', 'undersampleStyle': 'REDUCE_INTERP_ORDER', 'binSize': 128, 'binSizeX': 0, 'binSizeY': 0, 'algorithm': 'AKIMA_SPLINE', 'ignoredPixelMask': ['BAD', 'EDGE', 'DETECTED', 'DETECTED_NEGATIVE', 'NO_DATA'], 'isNanSafe': False, 'useApprox': True, 'approxOrderX': 6, 'approxOrderY': -1, 'weighting': True}, 'detection': {'minPixels': 1, 'isotropicGrow': False, 'nSigmaToGrow': 2.4, 'returnOriginalFootprints': False, 'thresholdValue': 5.0, 'includeThresholdMultiplier': 10.0, 'thresholdType': 'stdev', 'thresholdPolarity': 'positive', 'adjustBackground': 0.0, 'reEstimateBackground': True, 'background': {'statisticsProperty': 'MEANCLIP', 'undersampleStyle': 'REDUCE_INTERP_ORDER', 'binSize': 128, 'binSizeX': 0, 'binSizeY': 0, 'algorithm': 'AKIMA_SPLINE', 'ignoredPixelMask': ['BAD', 'EDGE', 'DETECTED', 'DETECTED_NEGATIVE', 'NO_DATA'], 'isNanSafe': False, 'useApprox': True, 'approxOrderX': 6, 'approxOrderY': -1, 'weighting': True}, 'tempLocalBackground': {'statisticsProperty': 'MEANCLIP', 'undersampleStyle': 'REDUCE_INTERP_ORDER', 'binSize': 64, 'binSizeX': 0, 'binSizeY': 0, 'algorithm': 'AKIMA_SPLINE', 'ignoredPixelMask': ['BAD', 'EDGE', 'DETECTED', 'DETECTED_NEGATIVE', 'NO_DATA'], 'isNanSafe': False, 'useApprox': False, 'approxOrderX': 6, 'approxOrderY': -1, 'weighting': True}, 'doTempLocalBackground': False, 'nPeaksMaxSimple': 1}, 'doDeblend': False, 'deblend': {'edgeHandling': 'ramp', 'strayFluxToPointSources': 'necessary', 'assignStrayFlux': True, 'strayFluxRule': 'trim', 'clipStrayFluxFraction': 0.001, 'psfChisq1': 1.5, 'psfChisq2': 1.5, 'psfChisq2b': 1.5, 'maxNumberOfPeaks': 0, 'maxFootprintArea': 1000000, 'maxFootprintSize': 0, 'minFootprintAxisRatio': 0.0, 'notDeblendedMask': 'NOT_DEBLENDED', 'tinyFootprintSize': 2, 'propagateAllPeaks': False, 'catchFailures': False, 'maskPlanes': ['SAT', 'INTRP', 'NO_DATA'], 'maskLimits': {}, 'weightTemplates': False, 'removeDegenerateTemplates': False, 'maxTempDotProd': 0.5, 'medianSmoothTemplate': True}, 'measurement': {'slots': {'centroid': 'base_SdssCentroid', 'shape': 'base_SdssShape', 'psfShape': 'base_SdssShape_psf', 'apFlux': 'base_CircularApertureFlux_12_0', 'modelFlux': 'base_GaussianFlux', 'psfFlux': 'base_PsfFlux', 'instFlux': 'base_GaussianFlux', 'calibFlux': 'base_CircularApertureFlux_12_0'}, 'doReplaceWithNoise': True, 'noiseReplacer': {'noiseSource': 'measure', 'noiseOffset': 0.0, 'noiseSeedMultiplier': 1}, 'undeblendedPrefix': 'undeblended_', 'plugins': {'names': ['base_PsfFlux', 'modelfit_DoubleShapeletPsfApprox', 'ext_convolved_ConvolvedFlux', 'modelfit_C ...
